# %% [markdown]
# # L9: Building LLM prompts with variables

# %% [markdown]
# In the next cell, you will import the function `print_llm_response` that uses an LLM with an instruction that you provide as a string and displays the result.

# %%
# !pip install openai
# !pip install python-dotenv
# !pip install aisetup
# Out:
# Requirement already satisfied: openai in /opt/anaconda3/lib/python3.13/site-packages (1.109.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from openai) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.13/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.13/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/lib/python3.13/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/anaconda3/lib/python3.13/site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: python-dotenv in /opt/anaconda3/lib/python3.13/site-packages (1.1.0)
# Requirement already satisfied: aisetup in /opt/anaconda3/lib/python3.13/site-packages (0.1.9)
# Requirement already satisfied: folium<0.18,>=0.17 in /opt/anaconda3/lib/python3.13/site-packages (from aisetup) (0.17.0)
# Requirement already satisfied: ipython<9.0,>=8.18 in /opt/anaconda3/lib/python3.13/site-packages (from aisetup) (8.30.0)
# Requirement already satisfied: ipywidgets<9.0.0,>=8.1.3 in /opt/anaconda3/lib/python3.13/site-packages (from aisetup) (8.1.5)
# Requirement already satisfied: matplotlib<4.0.0,>=3.9.2 in /opt/anaconda3/lib/python3.13/site-packages (from aisetup) (3.10.0)
# Requirement already satisfied: openai<2.0,>=1.42 in /opt/anaconda3/lib/python3.13/site-packages (from aisetup) (1.109.1)
# Requirement already satisfied: pandas<3.0,>=2.2 in /opt/anaconda3/lib/python3.13/site-packages (from aisetup) (2.2.3)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from aisetup) (1.1.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /opt/anaconda3/lib/python3.13/site-packages (from aisetup) (2.32.3)
# Requirement already satisfied: branca>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from folium<0.18,>=0.17->aisetup) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /opt/anaconda3/lib/python3.13/site-packages (from folium<0.18,>=0.17->aisetup) (3.1.6)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (from folium<0.18,>=0.17->aisetup) (2.1.3)
# Requirement already satisfied: xyzservices in /opt/anaconda3/lib/python3.13/site-packages (from folium<0.18,>=0.17->aisetup) (2022.9.0)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.13/site-packages (from ipython<9.0,>=8.18->aisetup) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from ipython<9.0,>=8.18->aisetup) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.13/site-packages (from ipython<9.0,>=8.18->aisetup) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.13/site-packages (from ipython<9.0,>=8.18->aisetup) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipython<9.0,>=8.18->aisetup) (2.19.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.13/site-packages (from ipython<9.0,>=8.18->aisetup) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipython<9.0,>=8.18->aisetup) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.13/site-packages (from ipython<9.0,>=8.18->aisetup) (4.8.0)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets<9.0.0,>=8.1.3->aisetup) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets<9.0.0,>=8.1.3->aisetup) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets<9.0.0,>=8.1.3->aisetup) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4.0.0,>=3.9.2->aisetup) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4.0.0,>=3.9.2->aisetup) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4.0.0,>=3.9.2->aisetup) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4.0.0,>=3.9.2->aisetup) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4.0.0,>=3.9.2->aisetup) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4.0.0,>=3.9.2->aisetup) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4.0.0,>=3.9.2->aisetup) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4.0.0,>=3.9.2->aisetup) (2.9.0.post0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from openai<2.0,>=1.42->aisetup) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from openai<2.0,>=1.42->aisetup) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.13/site-packages (from openai<2.0,>=1.42->aisetup) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from openai<2.0,>=1.42->aisetup) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from openai<2.0,>=1.42->aisetup) (2.11.7)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.13/site-packages (from openai<2.0,>=1.42->aisetup) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/lib/python3.13/site-packages (from openai<2.0,>=1.42->aisetup) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/anaconda3/lib/python3.13/site-packages (from openai<2.0,>=1.42->aisetup) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai<2.0,>=1.42->aisetup) (3.7)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai<2.0,>=1.42->aisetup) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai<2.0,>=1.42->aisetup) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0,>=1.42->aisetup) (0.16.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas<3.0,>=2.2->aisetup) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas<3.0,>=2.2->aisetup) (2025.2)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.13/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<9.0,>=8.18->aisetup) (0.2.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai<2.0,>=1.42->aisetup) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai<2.0,>=1.42->aisetup) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai<2.0,>=1.42->aisetup) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.32.3->aisetup) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.32.3->aisetup) (2.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/lib/python3.13/site-packages (from jedi>=0.16->ipython<9.0,>=8.18->aisetup) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2>=2.9->folium<0.18,>=0.17->aisetup) (3.0.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.13/site-packages (from pexpect>4.3->ipython<9.0,>=8.18->aisetup) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.9.2->aisetup) (1.17.0)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython<9.0,>=8.18->aisetup) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython<9.0,>=8.18->aisetup) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython<9.0,>=8.18->aisetup) (0.2.2)

# %%
# import os
# os.environ["OPENAI_API_KEY"] = "sk-proj-..."
# from openai import OpenAI
from aisetup import print_llm_response

# %% [markdown]
# Basically, you can use that function as if you were asking a chatbot. You just need to provide your instructions as a string. For instance, you can ask "What is the capital of France?" using the following code:

# %%
print_llm_response("What is the capital of France?")
# Out:
# The capital of France is Paris.

# %% [markdown]
# Let's ask the LLM for the lifestyle description for Otto Matic, whose name is stored in `name`, if he were a `dog_age` years old dog.

# %%
name = "Otto Matic"
dog_age = 21/7

# %%
print_llm_response(f"""If {name} were a dog, he would be {dog_age} years old.
Describe what life stage that would be for a dog and what that might 
entail in terms of energy level, interests, and behavior.""")
# Out:
# At 3.0 years old, a dog is typically considered to be in the young adult stage.
#
# **Energy Level:** High energy; they are usually very active and playful.
#
# **Interests:** Enjoys physical activities like running, playing fetch, and exploring. May also be interested in training and learning new tricks.
#
# **Behavior:** Generally more focused and less impulsive than a puppy. They may be more social and confident, often forming strong bonds with their owners and other dogs. They might also exhibit some independence.
#
# Overall, a 3-year-old dog is likely to be lively, engaged, and eager for both play and companionship.

# %% [markdown]
# <b>You just used AI with your own variables!</b> You used an LLM with instructions that included variables you defined in this notebook.
#
# <b>Congratulations 🎉🎉🎉</b>

# %% [markdown]
# ## Variable names restrictions

# %% [markdown]
# The following variable names also have some problems. Try to fix them yourself or use the help from the chatbot.

# %%
driver = "unicorn"
driver's vehicle = "colorful, asymmetric dinosaur car"
favorite planet = "Pluto
# Out:
#   Cell In[10], line 2
#     driver's vehicle = "colorful, asymmetric dinosaur car"
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %% [markdown]
# Now, update the next cell with any changes you made in the previous cell.

# %%
print_llm_response(f"""Write me a 300 word children's story about a {driver} racing
a {driver's vehicle} for the {favorite planet} champion cup.""")
# Out:
#   Cell In[11], line 2
#     a {driver's vehicle} for the {favorite planet} champion cup.""")
#                                                                    ^
# SyntaxError: f-string: unterminated string

# %% [markdown]
# ## Extra practice
#
# Try the exercises below to practice the concepts from this lesson. Read the comments in each cell with the instructions for each exercise.
#
# <b>Feel free to use the chatbot if you need help.</b>

# %%
# Fix this code
1favorite-book = "1001 Ways to Wear a Hat"
"2002 Ways to Wear a Scarf" = second_fav_book
print(f"My most favorite book is {1favorite-book}, but I also like {second_fav_book})
# Out:
#   Cell In[12], line 2
#     1favorite-book = "1001 Ways to Wear a Hat"
#     ^
# SyntaxError: invalid decimal literal

# %%
# Make variables for your favorite game, movie, and food.
# Then use print_llm_response to ask the LLM to recommend you
# a new song to listen to based on your likes.

print_llm_response(f"""

""")
# Out:
# How can I assist you today?
