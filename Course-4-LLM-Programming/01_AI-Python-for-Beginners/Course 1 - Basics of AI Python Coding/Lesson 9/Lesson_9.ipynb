# %% [markdown]
# # L9: Building LLM prompts with variables

# %% [markdown]
# In the next cell, you will import the function `print_llm_response` that uses an LLM with an instruction that you provide as a string and displays the result.

# %%
# !pip install openai
# !pip install python-dotenv
# !pip install aisetup
# Out:
# Requirement already satisfied: openai in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (2.3.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from openai) (0.11.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from openai) (2.12.0)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from openai) (4.14.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: python-dotenv in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (1.1.1)
# Collecting aisetup
#   Downloading aisetup-0.1.9-py3-none-any.whl.metadata (1.2 kB)
# Collecting folium<0.18,>=0.17 (from aisetup)
#   Downloading folium-0.17.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: ipython<9.0,>=8.18 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from aisetup) (8.37.0)
# Collecting ipywidgets<9.0.0,>=8.1.3 (from aisetup)
#   Downloading ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Collecting matplotlib<4.0.0,>=3.9.2 (from aisetup)
#   Downloading matplotlib-3.10.7-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting openai<2.0,>=1.42 (from aisetup)
#   Downloading openai-1.109.1-py3-none-any.whl.metadata (29 kB)
# Collecting pandas<3.0,>=2.2 (from aisetup)
#   Downloading pandas-2.3.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from aisetup) (1.1.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from aisetup) (2.32.4)
# Collecting branca>=0.6.0 (from folium<0.18,>=0.17->aisetup)
#   Downloading branca-0.8.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from folium<0.18,>=0.17->aisetup) (3.1.6)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from folium<0.18,>=0.17->aisetup) (2.2.6)
# Collecting xyzservices (from folium<0.18,>=0.17->aisetup)
#   Downloading xyzservices-2025.4.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from ipython<9.0,>=8.18->aisetup) (0.4.6)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from ipython<9.0,>=8.18->aisetup) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from ipython<9.0,>=8.18->aisetup) (1.3.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from ipython<9.0,>=8.18->aisetup) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from ipython<9.0,>=8.18->aisetup) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from ipython<9.0,>=8.18->aisetup) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from ipython<9.0,>=8.18->aisetup) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from ipython<9.0,>=8.18->aisetup) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from ipython<9.0,>=8.18->aisetup) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from ipython<9.0,>=8.18->aisetup) (4.14.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from ipywidgets<9.0.0,>=8.1.3->aisetup) (0.2.2)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets<9.0.0,>=8.1.3->aisetup)
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets<9.0.0,>=8.1.3->aisetup)
#   Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Collecting contourpy>=1.0.1 (from matplotlib<4.0.0,>=3.9.2->aisetup)
#   Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib<4.0.0,>=3.9.2->aisetup)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<4.0.0,>=3.9.2->aisetup)
#   Downloading fonttools-4.60.1-cp310-cp310-win_amd64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib<4.0.0,>=3.9.2->aisetup)
#   Downloading kiwisolver-1.4.9-cp310-cp310-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from matplotlib<4.0.0,>=3.9.2->aisetup) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from matplotlib<4.0.0,>=3.9.2->aisetup) (11.3.0)
# Collecting pyparsing>=3 (from matplotlib<4.0.0,>=3.9.2->aisetup)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from matplotlib<4.0.0,>=3.9.2->aisetup) (2.9.0.post0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from openai<2.0,>=1.42->aisetup) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from openai<2.0,>=1.42->aisetup) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from openai<2.0,>=1.42->aisetup) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from openai<2.0,>=1.42->aisetup) (0.11.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from openai<2.0,>=1.42->aisetup) (2.12.0)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from openai<2.0,>=1.42->aisetup) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from openai<2.0,>=1.42->aisetup) (4.67.1)
# Requirement already satisfied: idna>=2.8 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0,>=1.42->aisetup) (3.10)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0,>=1.42->aisetup) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0,>=1.42->aisetup) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0,>=1.42->aisetup) (0.16.0)
# Collecting pytz>=2020.1 (from pandas<3.0,>=2.2->aisetup)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3.0,>=2.2->aisetup)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<9.0,>=8.18->aisetup) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from pydantic<3,>=1.9.0->openai<2.0,>=1.42->aisetup) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from pydantic<3,>=1.9.0->openai<2.0,>=1.42->aisetup) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from pydantic<3,>=1.9.0->openai<2.0,>=1.42->aisetup) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from requests<3.0.0,>=2.32.3->aisetup) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from requests<3.0.0,>=2.32.3->aisetup) (2.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from jedi>=0.16->ipython<9.0,>=8.18->aisetup) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from jinja2>=2.9->folium<0.18,>=0.17->aisetup) (3.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.9.2->aisetup) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from stack_data->ipython<9.0,>=8.18->aisetup) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from stack_data->ipython<9.0,>=8.18->aisetup) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\user\anaconda3\envs\rl_env\lib\site-packages (from stack_data->ipython<9.0,>=8.18->aisetup) (0.2.3)
# Downloading aisetup-0.1.9-py3-none-any.whl (6.8 kB)
# Downloading folium-0.17.0-py2.py3-none-any.whl (108 kB)
# Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Downloading matplotlib-3.10.7-cp310-cp310-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -------------------------------------- - 7.9/8.1 MB 40.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 35.8 MB/s eta 0:00:00
# Downloading openai-1.109.1-py3-none-any.whl (948 kB)
#    ---------------------------------------- 0.0/948.6 kB ? eta -:--:--
#    --------------------------------------- 948.6/948.6 kB 42.9 MB/s eta 0:00:00
# Downloading pandas-2.3.3-cp310-cp310-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 11.3/11.3 MB 78.6 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 62.4 MB/s eta 0:00:00
# Downloading branca-0.8.2-py3-none-any.whl (26 kB)
# Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp310-cp310-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 125.9 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp310-cp310-win_amd64.whl (73 kB)
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading xyzservices-2025.4.0-py3-none-any.whl (90 kB)
# Installing collected packages: pytz, xyzservices, widgetsnbextension, tzdata, pyparsing, kiwisolver, jupyterlab_widgets, fonttools, cycler, contourpy, pandas, matplotlib, branca, ipywidgets, folium, openai, aisetup
#
#    ----------------------------------------  0/17 [pytz]
#    ----------------------------------------  0/17 [pytz]
#    ----------------------------------------  0/17 [pytz]
#    ---- -----------------------------------  2/17 [widgetsnbextension]
#    ------- --------------------------------  3/17 [tzdata]
#    ------- --------------------------------  3/17 [tzdata]
#    ------- --------------------------------  3/17 [tzdata]
#    --------- ------------------------------  4/17 [pyparsing]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    ---------------- -----------------------  7/17 [fonttools]
#    --------------------- ------------------  9/17 [contourpy]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ------------------------- -------------- 11/17 [matplotlib]
#    ------------------------- -------------- 11/17 [matplotlib]
#    ------------------------- -------------- 11/17 [matplotlib]
#    ------------------------- -------------- 11/17 [matplotlib]
#    ------------------------- -------------- 11/17 [matplotlib]
#    ------------------------- -------------- 11/17 [matplotlib]
#    ------------------------- -------------- 11/17 [matplotlib]
#    ------------------------- -------------- 11/17 [matplotlib]
#    ------------------------- -------------- 11/17 [matplotlib]
#    ------------------------- -------------- 11/17 [matplotlib]
#    ------------------------- -------------- 11/17 [matplotlib]
#    ------------------------- -------------- 11/17 [matplotlib]
#    ------------------------- -------------- 11/17 [matplotlib]
#    ------------------------- -------------- 11/17 [matplotlib]
#    ------------------------------ --------- 13/17 [ipywidgets]
#    ------------------------------ --------- 13/17 [ipywidgets]
#    -------------------------------- ------- 14/17 [folium]
#   Attempting uninstall: openai
#    -------------------------------- ------- 14/17 [folium]
#     Found existing installation: openai 2.3.0
#    -------------------------------- ------- 14/17 [folium]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#     Uninstalling openai-2.3.0:
#    ----------------------------------- ---- 15/17 [openai]
#       Successfully uninstalled openai-2.3.0
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ----------------------------------- ---- 15/17 [openai]
#    ---------------------------------------- 17/17 [aisetup]
#
# Successfully installed aisetup-0.1.9 branca-0.8.2 contourpy-1.3.2 cycler-0.12.1 folium-0.17.0 fonttools-4.60.1 ipywidgets-8.1.7 jupyterlab_widgets-3.0.15 kiwisolver-1.4.9 matplotlib-3.10.7 openai-1.109.1 pandas-2.3.3 pyparsing-3.2.5 pytz-2025.2 tzdata-2025.2 widgetsnbextension-4.0.14 xyzservices-2025.4.0

# %%
# import os
# os.environ["OPENAI_API_KEY"] = "sk-proj-..."
# from openai import OpenAI
from aisetup import print_llm_response

# %% [markdown]
# Basically, you can use that function as if you were asking a chatbot. You just need to provide your instructions as a string. For instance, you can ask "What is the capital of France?" using the following code:

# %%
print_llm_response("What is the capital of France?")
# Out:
# The capital of France is Paris.

# %% [markdown]
# Let's ask the LLM for the lifestyle description for Otto Matic, whose name is stored in `name`, if he were a `dog_age` years old dog.

# %%
name = "Otto Matic"
dog_age = 21/7

# %%
print_llm_response(f"""If {name} were a dog, he would be {dog_age} years old.
Describe what life stage that would be for a dog and what that might 
entail in terms of energy level, interests, and behavior.""")
# Out:
# At 3.0 years old, a dog is typically considered to be in the young adult stage.
#
# **Energy Level:** High energy; they are usually very active and playful.
#
# **Interests:** Enjoys physical activities like running, playing fetch, and exploring. May also be interested in training and learning new tricks.
#
# **Behavior:** Generally more focused and less impulsive than a puppy. They may be more social and confident, often forming strong bonds with their owners and other dogs. They might also exhibit some independence.
#
# Overall, a 3-year-old dog is likely to be lively, engaged, and eager for both play and companionship.

# %% [markdown]
# <b>You just used AI with your own variables!</b> You used an LLM with instructions that included variables you defined in this notebook.
#
# <b>Congratulations 🎉🎉🎉</b>

# %% [markdown]
# ## Variable names restrictions

# %% [markdown]
# The following variable names also have some problems. Try to fix them yourself or use the help from the chatbot.

# %%
driver = "unicorn"
driver's vehicle = "colorful, asymmetric dinosaur car"
favorite planet = "Pluto
# Out:
#   Cell In[10], line 2
#     driver's vehicle = "colorful, asymmetric dinosaur car"
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %% [markdown]
# Now, update the next cell with any changes you made in the previous cell.

# %%
print_llm_response(f"""Write me a 300 word children's story about a {driver} racing
a {driver's vehicle} for the {favorite planet} champion cup.""")
# Out:
#   Cell In[11], line 2
#     a {driver's vehicle} for the {favorite planet} champion cup.""")
#                                                                    ^
# SyntaxError: f-string: unterminated string

# %% [markdown]
# ## Extra practice
#
# Try the exercises below to practice the concepts from this lesson. Read the comments in each cell with the instructions for each exercise.
#
# <b>Feel free to use the chatbot if you need help.</b>

# %%
# Fix this code
1favorite-book = "1001 Ways to Wear a Hat"
"2002 Ways to Wear a Scarf" = second_fav_book
print(f"My most favorite book is {1favorite-book}, but I also like {second_fav_book})
# Out:
#   Cell In[12], line 2
#     1favorite-book = "1001 Ways to Wear a Hat"
#     ^
# SyntaxError: invalid decimal literal

# %%
# Make variables for your favorite game, movie, and food.
# Then use print_llm_response to ask the LLM to recommend you
# a new song to listen to based on your likes.

print_llm_response(f"""

""")
# Out:
# How can I assist you today?
