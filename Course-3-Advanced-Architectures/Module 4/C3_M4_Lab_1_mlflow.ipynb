# %% [markdown]
# # PyTorch Model Training with MLflow & Lightning: Tracking & Management
#
# Welcome to this hands-on lab! You've likely experienced the frustration of training a model for hours, achieving great accuracy, only to have it disappear when your notebook kernel restarts. This happens because a trained model exists only in memory; to preserve your work, you need a way to save it to disk, a process known as serialization.
#
# This notebook moves you beyond simple training and into the essential practice of robust model management. You'll apply these concepts by training a PyTorch CNN using **PyTorch Lightning** and integrating a powerful tool, [MLflow](https://mlflow.org), to systematically track and organize your work, ensuring no effort is ever lost.
#
# By the end of this lab, you'll have hands-on experience with:
#
# * Using **Lightning** to simplify and organize your training code with `LightningModule` and `LightningDataModule`.
#
# * Creating custom **Lightning Callbacks** to extend functionality during training.
#
# * Setting up an **MLflow experiment** to serve as a dedicated container for your project's training runs.
#
# * Logging **hyperparameters** and tracking metrics so you always have a record of the exact settings and performance of each run.
#
# * Saving **model checkpoints** during training, creating snapshots of your best-performing models that you can reload instantly.
#
# * Logging **artifacts**, such as your saved model files and performance plots, directly to MLflow for easy access and comparison.
#
# * Accessing your results both through the interactive **MLflow UI** and programmatically with the **Python client**.

# %% [markdown]
# ## Imports

# %%
import sys
import time
import warnings

# Redirect stderr to a black hole to catch other potential messages
class BlackHole:
    def write(self, message):
        pass
    def flush(self):
        pass
sys.stderr = BlackHole()

# Ignore Python-level UserWarnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
import datetime
import logging
import os

import lightning.pytorch as pl
import matplotlib.pyplot as plt
import mlflow
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from lightning.pytorch.callbacks import Callback
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torchmetrics.classification import Accuracy, ConfusionMatrix

import helper_utils

torch.set_float32_matmul_precision('medium')
logging.getLogger("mlflow").setLevel(logging.ERROR)
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# ## Random Seed Initialization
#
# * Set a global random seed for PyTorch CPU and GPU operations.
#     * This is a crucial step for ensuring reproducibility of training results.

# %%
# Define the global random seed value
RANDOM_SEED = 42

# Set seed for PyTorch CPU operations
torch.manual_seed(RANDOM_SEED)

# Check if CUDA (GPU support) is available
if torch.cuda.is_available():
    # Set seed for PyTorch GPU operations on all available GPUs
    torch.cuda.manual_seed_all(RANDOM_SEED)

# %% [markdown]
# ## CIFAR-10 DataModule
#
# * Create a `LightningDataModule` to encapsulate all data loading logic including transformations, dataset downloads, and dataloader creation.

# %%
class CIFAR10DataModule(pl.LightningDataModule):
    """A LightningDataModule for the CIFAR10 dataset."""

    def __init__(self, data_dir='./CIFAR10_data', batch_size=128, num_workers=2):
        """
        Initializes the DataModule.

        Args:
            data_dir (str): Directory to store the data.
            batch_size (int): Number of samples per batch.
            num_workers (int): Number of subprocesses for data loading.
        """
        super().__init__()
        self.data_dir = data_dir
        self.batch_size = batch_size
        self.num_workers = num_workers
        
        # Define transformations for training data
        self.transform_train = transforms.Compose([
            transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize(mean=(0.4914, 0.4822, 0.4465), 
                               std=(0.2023, 0.1994, 0.2010)),
        ])
        
        # Define transformations for validation data
        self.transform_test = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean=(0.4914, 0.4822, 0.4465), 
                               std=(0.2023, 0.1994, 0.2010)),
        ])
        
        # CIFAR-10 class labels
        self.classes = ('plane', 'car', 'bird', 'cat', 'deer', 
                       'dog', 'frog', 'horse', 'ship', 'truck')

    def prepare_data(self):
        """Downloads the CIFAR10 dataset if not already present."""
        # Check if data already exists
        if os.path.exists(self.data_dir) and os.path.isdir(self.data_dir):
            print("CIFAR10 Data folder found locally. Loading from local.\n")
        else:
            print("CIFAR10 Data folder not found locally. Downloading data.\n")
            
        # Download the dataset (will skip if already exists)
        torchvision.datasets.CIFAR10(root=self.data_dir, train=True, download=True)
        torchvision.datasets.CIFAR10(root=self.data_dir, train=False, download=True)

    def setup(self, stage=None):
        """
        Assigns train/val datasets for use in dataloaders.

        Args:
            stage (str, optional): The stage of training (e.g., 'fit', 'test').
        """
        # Create the training dataset
        self.cifar_train = torchvision.datasets.CIFAR10(
            root=self.data_dir, train=True, transform=self.transform_train
        )
        
        # Create the validation dataset
        self.cifar_val = torchvision.datasets.CIFAR10(
            root=self.data_dir, train=False, transform=self.transform_test
        )
    
    def train_dataloader(self):
        """Returns the DataLoader for the training set."""
        return torch.utils.data.DataLoader(
            self.cifar_train, 
            batch_size=self.batch_size, 
            shuffle=True, 
            num_workers=self.num_workers
        )

    def val_dataloader(self):
        """Returns the DataLoader for the validation set."""
        return torch.utils.data.DataLoader(
            self.cifar_val, 
            batch_size=self.batch_size, 
            shuffle=False, 
            num_workers=self.num_workers
        )

# Instantiate the data module
data_module = CIFAR10DataModule()

# Get class names for later use
classes = data_module.classes

# %% [markdown]
# ## CNN Model Definition as LightningModule
#
# * Define a `SimpleCNNLightning` class, which extends `pl.LightningModule` and encapsulates the model architecture, training logic, and optimizer configuration.

# %%
class SimpleCNN(pl.LightningModule):
    """A Lightning-wrapped CNN for CIFAR10 image classification."""
    
    def __init__(self, learning_rate=0.001):
        """
        Initializes the LightningModule.
        
        Args:
            learning_rate (float): The learning rate for the optimizer.
        """
        super().__init__()
        # Save hyperparameters
        self.save_hyperparameters()
        
        # Define the model architecture
        self.model = nn.Sequential(
            # Convolutional layers
            nn.Conv2d(3, 32, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(64, 128, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            # Fully connected layers
            nn.Flatten(),
            nn.Linear(128 * 4 * 4, 512),
            nn.ReLU(),
            nn.Dropout(0.25),
            nn.Linear(512, 10)
        )
        
        # Loss function
        self.loss_fn = nn.CrossEntropyLoss()
        
        # Metrics
        self.train_accuracy = Accuracy(task="multiclass", num_classes=10)
        self.val_accuracy = Accuracy(task="multiclass", num_classes=10)
    
    def forward(self, x):
        """
        Defines the forward pass of the model.
        
        Args:
            x: The input tensor containing a batch of images.
            
        Returns:
            The output tensor (logits) from the model.
        """
        return self.model(x)
    
    def training_step(self, batch, batch_idx):
        """
        Performs a single training step.
        
        Args:
            batch: The data batch from the dataloader.
            batch_idx: The index of the current batch.
            
        Returns:
            The loss value for backpropagation.
        """
        inputs, labels = batch
        outputs = self(inputs)
        loss = self.loss_fn(outputs, labels)
        
        # Calculate accuracy
        preds = torch.argmax(outputs, dim=1)
        self.train_accuracy(preds, labels)
        
        # Log metrics
        self.log("train_loss", loss, prog_bar=True)
        self.log("train_acc", self.train_accuracy, prog_bar=True)
        
        return loss
    
    def validation_step(self, batch, batch_idx):
        """
        Performs a single validation step.
        
        Args:
            batch: The data batch from the dataloader.
            batch_idx: The index of the current batch.
        """
        inputs, labels = batch
        outputs = self(inputs)
        loss = self.loss_fn(outputs, labels)
        
        # Calculate accuracy
        preds = torch.argmax(outputs, dim=1)
        self.val_accuracy(preds, labels)
        
        # Log metrics
        self.log("val_loss", loss, prog_bar=True)
        self.log("val_acc", self.val_accuracy, prog_bar=True)
    
    def configure_optimizers(self):
        """
        Configures and returns the optimizer and learning rate scheduler.
        
        Returns:
            Dictionary containing optimizer and scheduler configuration.
        """
        optimizer = optim.Adam(self.parameters(), lr=self.hparams.learning_rate)
        scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3)
        
        return {
            "optimizer": optimizer,
            "lr_scheduler": {
                "scheduler": scheduler,
                "monitor": "val_loss",
                "interval": "epoch",
                "frequency": 1,
            },
        }

# %% [markdown]
# ## Confusion Matrix Plotting Function
#
# * Define `plot_confusion_matrix` to generate and save a visual confusion matrix from a pre-computed matrix tensor.
#     * MLflow can log various artifacts, including graphical plots like confusion matrices, to provide deeper insights into model performance.

# %%
def plot_confusion_matrix(cm, class_names):
    # Plotting the Confusion Matrix
    plt.figure(figsize=(10, 8))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45)
    plt.yticks(tick_marks, class_names)

    # Define a threshold for text color (white on dark, black on light)
    thresh = cm.max() / 2.
    # Iterate over each cell in the confusion matrix
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            # Add the count as text to the cell
            plt.text(j, i, format(cm[i, j], 'd'),
                     horizontalalignment="center",
                     # Set text color based on cell value and threshold
                     color="white" if cm[i, j] > thresh else "black")

    # Adjust plot layout to prevent labels from overlapping
    plt.tight_layout()
    # Set the y-axis label
    plt.ylabel('True label')
    # Set the x-axis label
    plt.xlabel('Predicted label')

    # Define the filename for the saved plot
    output_filename = 'confusion_matrix.png'
    # Save the plot to a file
    plt.savefig(output_filename)
    # Close the plot figure to free up memory
    plt.close()

    return output_filename

# %% [markdown]
# ## MLflow Logging Callback
#
# * While Lightning provides a built-in [MLFlowLogger](https://lightning.ai/docs/pytorch/stable/api/lightning.pytorch.loggers.mlflow.html) for standard experiment tracking, this lab uses a custom `Callback`. This approach allows for more advanced control, such as logging custom-generated plots and implementing unique checkpointing logic that the built-in logger does not support.
# * Define a custom Lightning `Callback` to automatically log metrics, hyperparameters, and artifacts to MLflow during training.

# %%
class MLflowLoggingCallback(Callback):
    """
    A Lightning Callback to log metrics, hyperparameters, and artifacts to MLflow.
    
    This callback handles:
    - Logging hyperparameters at the start of training
    - Logging metrics after each epoch
    - Saving and logging model checkpoints for best models
    - Logging the confusion matrix at the end of training
    """
    
    def __init__(self, classes):
        """
        Initialize the MLflow logging callback.
        
        Args:
            classes: Tuple of class names for the confusion matrix.
        """
        super().__init__()
        self.classes = classes
        self.best_accuracy = 0
        self.model_save_dir = "./best_model"
        os.makedirs(self.model_save_dir, exist_ok=True)
    
    def on_train_start(self, trainer, pl_module):
        """
        Log hyperparameters at the start of training.
        
        Args:
            trainer: The Lightning Trainer instance.
            pl_module: The LightningModule being trained.
        """
        # Log model hyperparameters
        mlflow.log_param("model_type", "SimpleCNN")
        mlflow.log_param("optimizer", "Adam")
        mlflow.log_param("initial_lr", pl_module.hparams.learning_rate)
        mlflow.log_param("scheduler", "ReduceLROnPlateau")
        mlflow.log_param("batch_size", trainer.datamodule.batch_size)
        mlflow.log_param("random_seed", RANDOM_SEED)
    
    def on_validation_epoch_end(self, trainer, pl_module):
        """
        Log metrics and save checkpoints after each validation epoch.
        
        Args:
            trainer: The Lightning Trainer instance.
            pl_module: The LightningModule being validated.
        """
        # Skip if in sanity checking mode
        if trainer.sanity_checking:
            return
        
        # Get current metrics
        metrics = trainer.callback_metrics
        current_epoch = trainer.current_epoch
        
        # Log metrics to MLflow
        if "train_loss" in metrics:
            mlflow.log_metric("train_loss", metrics["train_loss"].item(), step=current_epoch)
        if "val_loss" in metrics:
            mlflow.log_metric("val_loss", metrics["val_loss"].item(), step=current_epoch)
        if "val_acc" in metrics:
            accuracy = metrics["val_acc"].item() * 100
            mlflow.log_metric("accuracy", accuracy, step=current_epoch)
            
            # Log learning rate
            current_lr = trainer.optimizers[0].param_groups[0]['lr']
            mlflow.log_metric("learning_rate", current_lr, step=current_epoch)
            
            # Save checkpoint if this is the best model so far
            if accuracy > self.best_accuracy:
                self.best_accuracy = accuracy
                
                # Create checkpoint
                checkpoint = {
                    'epoch': current_epoch + 1,
                    'model_state_dict': pl_module.state_dict(),
                    'optimizer_state_dict': trainer.optimizers[0].state_dict(),
                    'val_loss': metrics["val_loss"].item(),
                    'accuracy': accuracy,
                    'random_seed': RANDOM_SEED
                }
                
                # Save checkpoint file
                checkpoint_filename = f'best_model_checkpoint_epoch_{current_epoch + 1}.pt'
                checkpoint_path = os.path.join(self.model_save_dir, checkpoint_filename)
                torch.save(checkpoint, checkpoint_path)
                
                # Log checkpoint to MLflow
                mlflow.log_artifact(checkpoint_path)
    
    def on_train_end(self, trainer, pl_module):
        """
        Log final metrics and artifacts at the end of training.
        
        Args:
            trainer: The Lightning Trainer instance.
            pl_module: The LightningModule that was trained.
        """
        # Log best accuracy
        mlflow.log_metric("best_accuracy", self.best_accuracy)
        
        # Generate and log confusion matrix
        print("\nCalculating final confusion matrix for artifact logging...")
        confmat_metric = ConfusionMatrix(task="multiclass", num_classes=10).to(pl_module.device)
        
        pl_module.eval()
        with torch.no_grad():
            for batch in trainer.val_dataloaders:
                images, labels = batch
                images, labels = images.to(pl_module.device), labels.to(pl_module.device)
                outputs = pl_module(images)
                preds = torch.argmax(outputs, dim=1)
                confmat_metric.update(preds, labels)
        
        final_cm = confmat_metric.compute().cpu().numpy()
        cm_path = plot_confusion_matrix(final_cm, self.classes)
        mlflow.log_artifact(cm_path)
        
        # Log the trained model
        input_example_tensor, _ = next(iter(trainer.val_dataloaders))
        input_example_numpy = input_example_tensor.cpu().numpy()
        
        # Move model to CPU for serialization
        pl_module.to("cpu")
        
        # Log the PyTorch model to MLflow
        mlflow.pytorch.log_model(
            pytorch_model=pl_module,
            artifact_path="cifar10_cnn_model_final",
            input_example=input_example_numpy
        )
        
        print(f'\nFinished Training. Best accuracy: {self.best_accuracy:.2f}%')

# %% [markdown]
# ## MLflow Experiment Setup
#
# * Set the active MLflow experiment to "CIFAR10_CNN_Lightning" using [mlflow.set_experiment()](https://mlflow.org/docs/latest/api_reference/python_api/mlflow.html?highlight=set_experiment#mlflow.set_experiment).
#     * By default, the name of the experiment is set to `CIFAR10_CNN_Lightning`. You can rename it to anything you want.
# * Organizing runs within named experiments is a fundamental aspect of using MLflow for structured experiment tracking.

# %%
# Set or create an MLflow experiment named "CIFAR10_CNN_Lightning"
mlflow.set_experiment("CIFAR10_CNN")
# Out:
# <Experiment: artifact_location='file:///home/jovyan/work/mlruns/366944453960856762', creation_time=1767516807900, experiment_id='366944453960856762', last_update_time=1767516807900, lifecycle_stage='active', name='CIFAR10_CNN', tags={}>

# %% [markdown]
# ## MLflow Run and Training with Lightning Trainer
#
# * Begin an MLflow run context using `mlflow.start_run()`, which groups all subsequent logging under a single run ID.
# * **Lightning Trainer Setup**:
#     * Configure the Lightning `Trainer` with essential parameters:
#         * `max_epochs`: Number of training epochs
#         * `accelerator="auto"`: Automatically detect and use available hardware (GPU/CPU)
#         * `devices=1`: Use a single device
#         * `logger=False`: Disable default Lightning logging (we use MLflow instead)
#         * `callbacks`: Pass the `MLflowLoggingCallback` to handle all MLflow logging
#         * `enable_progress_bar=True`: Show training progress
# * **Training Execution**:
#     * Call `trainer.fit(model, data_module)` to run the entire training loop automatically
#     * Lightning handles all the training/validation loops, gradient updates, and device management
#     * The callback handles all MLflow logging throughout the process

# %%
# Start an MLflow run context
with mlflow.start_run() as run:
    
    # Define the total number of training epochs
    num_epochs = 10
    
    # Create the model
    model = SimpleCNN(learning_rate=0.001)
    
    # Create the MLflow logging callback
    mlflow_callback = MLflowLoggingCallback(classes=classes)
    
    # Configure the Lightning Trainer
    trainer = pl.Trainer(
        max_epochs=num_epochs,
        accelerator="auto",
        devices=1,
        logger=False,  # Disable default Lightning logging
        callbacks=[mlflow_callback],
        enable_progress_bar=True,
        enable_model_summary=True,
        enable_checkpointing=False  # We handle checkpointing in the callback
    )
    
    # Train the model
    trainer.fit(model, data_module)
    
    print(f'\nMLflow run id: {run.info.run_id}')
    print('To view results run mlflow ui')
# Out:
# CIFAR10 Data folder found locally. Loading from local.
#
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0: 100%|██████████| 391/391 [00:11<00:00, 32.85it/s, train_loss=1.390, train_acc=0.550]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏         | 1/79 [00:00<00:01, 71.47it/s]
# Validation DataLoader 0:   3%|▎         | 2/79 [00:00<00:00, 78.75it/s]
# Validation DataLoader 0:   4%|▍         | 3/79 [00:00<00:00, 79.26it/s]
# Validation DataLoader 0:   5%|▌         | 4/79 [00:00<00:01, 69.21it/s]
# Validation DataLoader 0:   6%|▋         | 5/79 [00:00<00:01, 73.56it/s]
# Validation DataLoader 0:   8%|▊         | 6/79 [00:00<00:01, 65.73it/s]
# Validation DataLoader 0:   9%|▉         | 7/79 [00:00<00:01, 68.72it/s]
# Validation DataLoader 0:  10%|█         | 8/79 [00:00<00:01, 63.57it/s]
# Validation DataLoader 0:  11%|█▏        | 9/79 [00:00<00:01, 67.19it/s]
# Validation DataLoader 0:  13%|█▎        | 10/79 [00:00<00:01, 58.41it/s]
# Validation DataLoader 0:  14%|█▍        | 11/79 [00:00<00:01, 60.30it/s]
# Validation DataLoader 0:  15%|█▌        | 12/79 [00:00<00:01, 59.62it/s]
# Validation DataLoader 0:  16%|█▋        | 13/79 [00:00<00:01, 61.21it/s]
# Validation DataLoader 0:  18%|█▊        | 14/79 [00:00<00:01, 60.50it/s]
# Validation DataLoader 0:  19%|█▉        | 15/79 [00:00<00:01, 60.46it/s]
# Validation DataLoader 0:  20%|██        | 16/79 [00:00<00:01, 60.76it/s]
# Validation DataLoader 0:  22%|██▏       | 17/79 [00:00<00:01, 60.40it/s]
# Validation DataLoader 0:  23%|██▎       | 18/79 [00:00<00:01, 60.10it/s]
# Validation DataLoader 0:  24%|██▍       | 19/79 [00:00<00:00, 61.15it/s]
# Validation DataLoader 0:  25%|██▌       | 20/79 [00:00<00:00, 60.04it/s]
# Validation DataLoader 0:  27%|██▋       | 21/79 [00:00<00:00, 60.68it/s]
# Validation DataLoader 0:  28%|██▊       | 22/79 [00:00<00:00, 59.87it/s]
# Validation DataLoader 0:  29%|██▉       | 23/79 [00:00<00:00, 61.14it/s]
# Validation DataLoader 0:  30%|███       | 24/79 [00:00<00:00, 59.27it/s]
# Validation DataLoader 0:  32%|███▏      | 25/79 [00:00<00:00, 59.64it/s]
# Validation DataLoader 0:  33%|███▎      | 26/79 [00:00<00:00, 57.88it/s]
# Validation DataLoader 0:  34%|███▍      | 27/79 [00:00<00:00, 58.28it/s]
# Validation DataLoader 0:  35%|███▌      | 28/79 [00:00<00:00, 56.51it/s]
# Validation DataLoader 0:  37%|███▋      | 29/79 [00:00<00:00, 56.93it/s]
# Validation DataLoader 0:  38%|███▊      | 30/79 [00:00<00:00, 56.96it/s]
# Validation DataLoader 0:  39%|███▉      | 31/79 [00:00<00:00, 56.80it/s]
# Validation DataLoader 0:  41%|████      | 32/79 [00:00<00:00, 57.36it/s]
# Validation DataLoader 0:  42%|████▏     | 33/79 [00:00<00:00, 56.76it/s]
# Validation DataLoader 0:  43%|████▎     | 34/79 [00:00<00:00, 57.26it/s]
# Validation DataLoader 0:  44%|████▍     | 35/79 [00:00<00:00, 56.69it/s]
# Validation DataLoader 0:  46%|████▌     | 36/79 [00:00<00:00, 57.29it/s]
# Validation DataLoader 0:  47%|████▋     | 37/79 [00:00<00:00, 56.59it/s]
# Validation DataLoader 0:  48%|████▊     | 38/79 [00:00<00:00, 56.94it/s]
# Validation DataLoader 0:  49%|████▉     | 39/79 [00:00<00:00, 56.44it/s]
# Validation DataLoader 0:  51%|█████     | 40/79 [00:00<00:00, 57.09it/s]
# Validation DataLoader 0:  52%|█████▏    | 41/79 [00:00<00:00, 56.30it/s]
# Validation DataLoader 0:  53%|█████▎    | 42/79 [00:00<00:00, 56.95it/s]
# Validation DataLoader 0:  54%|█████▍    | 43/79 [00:00<00:00, 56.45it/s]
# Validation DataLoader 0:  56%|█████▌    | 44/79 [00:00<00:00, 57.08it/s]
# Validation DataLoader 0:  57%|█████▋    | 45/79 [00:00<00:00, 56.43it/s]
# Validation DataLoader 0:  58%|█████▊    | 46/79 [00:00<00:00, 57.17it/s]
# Validation DataLoader 0:  59%|█████▉    | 47/79 [00:00<00:00, 55.91it/s]
# Validation DataLoader 0:  61%|██████    | 48/79 [00:00<00:00, 56.58it/s]
# Validation DataLoader 0:  62%|██████▏   | 49/79 [00:00<00:00, 55.38it/s]
# Validation DataLoader 0:  63%|██████▎   | 50/79 [00:00<00:00, 56.03it/s]
# Validation DataLoader 0:  65%|██████▍   | 51/79 [00:00<00:00, 54.89it/s]
# Validation DataLoader 0:  66%|██████▌   | 52/79 [00:00<00:00, 55.50it/s]
# Validation DataLoader 0:  67%|██████▋   | 53/79 [00:00<00:00, 54.43it/s]
# Validation DataLoader 0:  68%|██████▊   | 54/79 [00:00<00:00, 55.01it/s]
# Validation DataLoader 0:  70%|██████▉   | 55/79 [00:01<00:00, 54.02it/s]
# Validation DataLoader 0:  71%|███████   | 56/79 [00:01<00:00, 54.47it/s]
# Validation DataLoader 0:  72%|███████▏  | 57/79 [00:01<00:00, 54.12it/s]
# Validation DataLoader 0:  73%|███████▎  | 58/79 [00:01<00:00, 54.58it/s]
# Validation DataLoader 0:  75%|███████▍  | 59/79 [00:01<00:00, 54.29it/s]
# Validation DataLoader 0:  76%|███████▌  | 60/79 [00:01<00:00, 54.73it/s]
# Validation DataLoader 0:  77%|███████▋  | 61/79 [00:01<00:00, 54.01it/s]
# Validation DataLoader 0:  78%|███████▊  | 62/79 [00:01<00:00, 54.44it/s]
# Validation DataLoader 0:  80%|███████▉  | 63/79 [00:01<00:00, 54.04it/s]
# Validation DataLoader 0:  81%|████████  | 64/79 [00:01<00:00, 54.49it/s]
# Validation DataLoader 0:  82%|████████▏ | 65/79 [00:01<00:00, 54.19it/s]
# Validation DataLoader 0:  84%|████████▎ | 66/79 [00:01<00:00, 54.62it/s]
# Validation DataLoader 0:  85%|████████▍ | 67/79 [00:01<00:00, 54.25it/s]
# Validation DataLoader 0:  86%|████████▌ | 68/79 [00:01<00:00, 54.69it/s]
# Validation DataLoader 0:  87%|████████▋ | 69/79 [00:01<00:00, 54.39it/s]
# Validation DataLoader 0:  89%|████████▊ | 70/79 [00:01<00:00, 54.79it/s]
# Validation DataLoader 0:  90%|████████▉ | 71/79 [00:01<00:00, 54.51it/s]
# Validation DataLoader 0:  91%|█████████ | 72/79 [00:01<00:00, 54.77it/s]
# Validation DataLoader 0:  92%|█████████▏| 73/79 [00:01<00:00, 54.33it/s]
# Validation DataLoader 0:  94%|█████████▎| 74/79 [00:01<00:00, 54.78it/s]
# Validation DataLoader 0:  95%|█████████▍| 75/79 [00:01<00:00, 54.06it/s]
# Validation DataLoader 0:  96%|█████████▌| 76/79 [00:01<00:00, 54.50it/s]
# Validation DataLoader 0:  97%|█████████▋| 77/79 [00:01<00:00, 54.23it/s]
# Validation DataLoader 0:  99%|█████████▊| 78/79 [00:01<00:00, 54.67it/s]
# Validation DataLoader 0: 100%|██████████| 79/79 [00:01<00:00, 53.91it/s]
# Epoch 1: 100%|██████████| 391/391 [00:12<00:00, 32.26it/s, train_loss=1.150, train_acc=0.600, val_loss=1.190, val_acc=0.572]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏         | 1/79 [00:00<00:00, 95.29it/s]
# Validation DataLoader 0:   3%|▎         | 2/79 [00:00<00:01, 41.11it/s]
# Validation DataLoader 0:   4%|▍         | 3/79 [00:00<00:01, 52.31it/s]
# Validation DataLoader 0:   5%|▌         | 4/79 [00:00<00:01, 41.71it/s]
# Validation DataLoader 0:   6%|▋         | 5/79 [00:00<00:01, 46.72it/s]
# Validation DataLoader 0:   8%|▊         | 6/79 [00:00<00:01, 46.28it/s]
# Validation DataLoader 0:   9%|▉         | 7/79 [00:00<00:01, 49.79it/s]
# Validation DataLoader 0:  10%|█         | 8/79 [00:00<00:01, 49.06it/s]
# Validation DataLoader 0:  11%|█▏        | 9/79 [00:00<00:01, 51.70it/s]
# Validation DataLoader 0:  13%|█▎        | 10/79 [00:00<00:01, 49.64it/s]
# Validation DataLoader 0:  14%|█▍        | 11/79 [00:00<00:01, 52.03it/s]
# Validation DataLoader 0:  15%|█▌        | 12/79 [00:00<00:01, 51.18it/s]
# Validation DataLoader 0:  16%|█▋        | 13/79 [00:00<00:01, 53.22it/s]
# Validation DataLoader 0:  18%|█▊        | 14/79 [00:00<00:01, 52.19it/s]
# Validation DataLoader 0:  19%|█▉        | 15/79 [00:00<00:01, 53.86it/s]
# Validation DataLoader 0:  20%|██        | 16/79 [00:00<00:01, 52.99it/s]
# Validation DataLoader 0:  22%|██▏       | 17/79 [00:00<00:01, 54.51it/s]
# Validation DataLoader 0:  23%|██▎       | 18/79 [00:00<00:01, 53.35it/s]
# Validation DataLoader 0:  24%|██▍       | 19/79 [00:00<00:01, 54.71it/s]
# Validation DataLoader 0:  25%|██▌       | 20/79 [00:00<00:01, 53.87it/s]
# Validation DataLoader 0:  27%|██▋       | 21/79 [00:00<00:01, 54.98it/s]
# Validation DataLoader 0:  28%|██▊       | 22/79 [00:00<00:01, 53.90it/s]
# Validation DataLoader 0:  29%|██▉       | 23/79 [00:00<00:01, 54.98it/s]
# Validation DataLoader 0:  30%|███       | 24/79 [00:00<00:01, 54.28it/s]
# Validation DataLoader 0:  32%|███▏      | 25/79 [00:00<00:00, 55.31it/s]
# Validation DataLoader 0:  33%|███▎      | 26/79 [00:00<00:00, 54.77it/s]
# Validation DataLoader 0:  34%|███▍      | 27/79 [00:00<00:00, 55.78it/s]
# Validation DataLoader 0:  35%|███▌      | 28/79 [00:00<00:00, 54.96it/s]
# Validation DataLoader 0:  37%|███▋      | 29/79 [00:00<00:00, 55.74it/s]
# Validation DataLoader 0:  38%|███▊      | 30/79 [00:00<00:00, 55.24it/s]
# Validation DataLoader 0:  39%|███▉      | 31/79 [00:00<00:00, 55.96it/s]
# Validation DataLoader 0:  41%|████      | 32/79 [00:00<00:00, 55.51it/s]
# Validation DataLoader 0:  42%|████▏     | 33/79 [00:00<00:00, 56.18it/s]
# Validation DataLoader 0:  43%|████▎     | 34/79 [00:00<00:00, 55.76it/s]
# Validation DataLoader 0:  44%|████▍     | 35/79 [00:00<00:00, 56.37it/s]
# Validation DataLoader 0:  46%|████▌     | 36/79 [00:00<00:00, 55.90it/s]
# Validation DataLoader 0:  47%|████▋     | 37/79 [00:00<00:00, 56.26it/s]
# Validation DataLoader 0:  48%|████▊     | 38/79 [00:00<00:00, 55.34it/s]
# Validation DataLoader 0:  49%|████▉     | 39/79 [00:00<00:00, 56.21it/s]
# Validation DataLoader 0:  51%|█████     | 40/79 [00:00<00:00, 54.72it/s]
# Validation DataLoader 0:  52%|█████▏    | 41/79 [00:00<00:00, 55.54it/s]
# Validation DataLoader 0:  53%|█████▎    | 42/79 [00:00<00:00, 54.21it/s]
# Validation DataLoader 0:  54%|█████▍    | 43/79 [00:00<00:00, 54.98it/s]
# Validation DataLoader 0:  56%|█████▌    | 44/79 [00:00<00:00, 53.73it/s]
# Validation DataLoader 0:  57%|█████▋    | 45/79 [00:00<00:00, 54.47it/s]
# Validation DataLoader 0:  58%|█████▊    | 46/79 [00:00<00:00, 53.31it/s]
# Validation DataLoader 0:  59%|█████▉    | 47/79 [00:00<00:00, 54.02it/s]
# Validation DataLoader 0:  61%|██████    | 48/79 [00:00<00:00, 52.93it/s]
# Validation DataLoader 0:  62%|██████▏   | 49/79 [00:00<00:00, 53.60it/s]
# Validation DataLoader 0:  63%|██████▎   | 50/79 [00:00<00:00, 52.49it/s]
# Validation DataLoader 0:  65%|██████▍   | 51/79 [00:00<00:00, 53.13it/s]
# Validation DataLoader 0:  66%|██████▌   | 52/79 [00:00<00:00, 52.19it/s]
# Validation DataLoader 0:  67%|██████▋   | 53/79 [00:01<00:00, 52.82it/s]
# Validation DataLoader 0:  68%|██████▊   | 54/79 [00:01<00:00, 51.91it/s]
# Validation DataLoader 0:  70%|██████▉   | 55/79 [00:01<00:00, 52.51it/s]
# Validation DataLoader 0:  71%|███████   | 56/79 [00:01<00:00, 51.63it/s]
# Validation DataLoader 0:  72%|███████▏  | 57/79 [00:01<00:00, 52.20it/s]
# Validation DataLoader 0:  73%|███████▎  | 58/79 [00:01<00:00, 51.39it/s]
# Validation DataLoader 0:  75%|███████▍  | 59/79 [00:01<00:00, 51.94it/s]
# Validation DataLoader 0:  76%|███████▌  | 60/79 [00:01<00:00, 51.16it/s]
# Validation DataLoader 0:  77%|███████▋  | 61/79 [00:01<00:00, 51.69it/s]
# Validation DataLoader 0:  78%|███████▊  | 62/79 [00:01<00:00, 50.95it/s]
# Validation DataLoader 0:  80%|███████▉  | 63/79 [00:01<00:00, 51.46it/s]
# Validation DataLoader 0:  81%|████████  | 64/79 [00:01<00:00, 50.73it/s]
# Validation DataLoader 0:  82%|████████▏ | 65/79 [00:01<00:00, 51.22it/s]
# Validation DataLoader 0:  84%|████████▎ | 66/79 [00:01<00:00, 50.56it/s]
# Validation DataLoader 0:  85%|████████▍ | 67/79 [00:01<00:00, 51.04it/s]
# Validation DataLoader 0:  86%|████████▌ | 68/79 [00:01<00:00, 50.39it/s]
# Validation DataLoader 0:  87%|████████▋ | 69/79 [00:01<00:00, 50.86it/s]
# Validation DataLoader 0:  89%|████████▊ | 70/79 [00:01<00:00, 50.25it/s]
# Validation DataLoader 0:  90%|████████▉ | 71/79 [00:01<00:00, 50.70it/s]
# Validation DataLoader 0:  91%|█████████ | 72/79 [00:01<00:00, 50.10it/s]
# Validation DataLoader 0:  92%|█████████▏| 73/79 [00:01<00:00, 50.54it/s]
# Validation DataLoader 0:  94%|█████████▎| 74/79 [00:01<00:00, 49.95it/s]
# Validation DataLoader 0:  95%|█████████▍| 75/79 [00:01<00:00, 50.37it/s]
# Validation DataLoader 0:  96%|█████████▌| 76/79 [00:01<00:00, 49.96it/s]
# Validation DataLoader 0:  97%|█████████▋| 77/79 [00:01<00:00, 50.32it/s]
# Validation DataLoader 0:  99%|█████████▊| 78/79 [00:01<00:00, 50.27it/s]
# Validation DataLoader 0: 100%|██████████| 79/79 [00:01<00:00, 50.75it/s]
# Epoch 2: 100%|██████████| 391/391 [00:11<00:00, 32.63it/s, train_loss=0.860, train_acc=0.675, val_loss=0.965, val_acc=0.657]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏         | 1/79 [00:00<00:00, 99.85it/s]
# Validation DataLoader 0:   3%|▎         | 2/79 [00:00<00:00, 79.83it/s]
# Validation DataLoader 0:   4%|▍         | 3/79 [00:00<00:01, 62.12it/s]
# Validation DataLoader 0:   5%|▌         | 4/79 [00:00<00:01, 57.46it/s]
# Validation DataLoader 0:   6%|▋         | 5/79 [00:00<00:01, 54.14it/s]
# Validation DataLoader 0:   8%|▊         | 6/79 [00:00<00:01, 52.72it/s]
# Validation DataLoader 0:   9%|▉         | 7/79 [00:00<00:01, 51.32it/s]
# Validation DataLoader 0:  10%|█         | 8/79 [00:00<00:01, 50.62it/s]
# Validation DataLoader 0:  11%|█▏        | 9/79 [00:00<00:01, 49.86it/s]
# Validation DataLoader 0:  13%|█▎        | 10/79 [00:00<00:01, 49.50it/s]
# Validation DataLoader 0:  14%|█▍        | 11/79 [00:00<00:01, 49.03it/s]
# Validation DataLoader 0:  15%|█▌        | 12/79 [00:00<00:01, 48.78it/s]
# Validation DataLoader 0:  16%|█▋        | 13/79 [00:00<00:01, 48.44it/s]
# Validation DataLoader 0:  18%|█▊        | 14/79 [00:00<00:01, 48.30it/s]
# Validation DataLoader 0:  19%|█▉        | 15/79 [00:00<00:01, 47.99it/s]
# Validation DataLoader 0:  20%|██        | 16/79 [00:00<00:01, 47.83it/s]
# Validation DataLoader 0:  22%|██▏       | 17/79 [00:00<00:01, 47.58it/s]
# Validation DataLoader 0:  23%|██▎       | 18/79 [00:00<00:01, 47.56it/s]
# Validation DataLoader 0:  24%|██▍       | 19/79 [00:00<00:01, 47.34it/s]
# Validation DataLoader 0:  25%|██▌       | 20/79 [00:00<00:01, 47.31it/s]
# Validation DataLoader 0:  27%|██▋       | 21/79 [00:00<00:01, 47.15it/s]
# Validation DataLoader 0:  28%|██▊       | 22/79 [00:00<00:01, 47.10it/s]
# Validation DataLoader 0:  29%|██▉       | 23/79 [00:00<00:01, 47.00it/s]
# Validation DataLoader 0:  30%|███       | 24/79 [00:00<00:01, 46.94it/s]
# Validation DataLoader 0:  32%|███▏      | 25/79 [00:00<00:01, 46.85it/s]
# Validation DataLoader 0:  33%|███▎      | 26/79 [00:00<00:01, 46.80it/s]
# Validation DataLoader 0:  34%|███▍      | 27/79 [00:00<00:01, 46.72it/s]
# Validation DataLoader 0:  35%|███▌      | 28/79 [00:00<00:01, 46.68it/s]
# Validation DataLoader 0:  37%|███▋      | 29/79 [00:00<00:01, 46.64it/s]
# Validation DataLoader 0:  38%|███▊      | 30/79 [00:00<00:01, 46.56it/s]
# Validation DataLoader 0:  39%|███▉      | 31/79 [00:00<00:01, 46.57it/s]
# Validation DataLoader 0:  41%|████      | 32/79 [00:00<00:01, 46.55it/s]
# Validation DataLoader 0:  42%|████▏     | 33/79 [00:00<00:00, 46.49it/s]
# Validation DataLoader 0:  43%|████▎     | 34/79 [00:00<00:00, 46.48it/s]
# Validation DataLoader 0:  44%|████▍     | 35/79 [00:00<00:00, 46.42it/s]
# Validation DataLoader 0:  46%|████▌     | 36/79 [00:00<00:00, 46.40it/s]
# Validation DataLoader 0:  47%|████▋     | 37/79 [00:00<00:00, 46.37it/s]
# Validation DataLoader 0:  48%|████▊     | 38/79 [00:00<00:00, 46.37it/s]
# Validation DataLoader 0:  49%|████▉     | 39/79 [00:00<00:00, 46.33it/s]
# Validation DataLoader 0:  51%|█████     | 40/79 [00:00<00:00, 46.31it/s]
# Validation DataLoader 0:  52%|█████▏    | 41/79 [00:00<00:00, 46.27it/s]
# Validation DataLoader 0:  53%|█████▎    | 42/79 [00:00<00:00, 46.27it/s]
# Validation DataLoader 0:  54%|█████▍    | 43/79 [00:00<00:00, 46.25it/s]
# Validation DataLoader 0:  56%|█████▌    | 44/79 [00:00<00:00, 46.25it/s]
# Validation DataLoader 0:  57%|█████▋    | 45/79 [00:00<00:00, 46.22it/s]
# Validation DataLoader 0:  58%|█████▊    | 46/79 [00:00<00:00, 46.22it/s]
# Validation DataLoader 0:  59%|█████▉    | 47/79 [00:01<00:00, 46.19it/s]
# Validation DataLoader 0:  61%|██████    | 48/79 [00:01<00:00, 46.19it/s]
# Validation DataLoader 0:  62%|██████▏   | 49/79 [00:01<00:00, 46.16it/s]
# Validation DataLoader 0:  63%|██████▎   | 50/79 [00:01<00:00, 46.18it/s]
# Validation DataLoader 0:  65%|██████▍   | 51/79 [00:01<00:00, 46.16it/s]
# Validation DataLoader 0:  66%|██████▌   | 52/79 [00:01<00:00, 46.15it/s]
# Validation DataLoader 0:  67%|██████▋   | 53/79 [00:01<00:00, 46.14it/s]
# Validation DataLoader 0:  68%|██████▊   | 54/79 [00:01<00:00, 46.09it/s]
# Validation DataLoader 0:  70%|██████▉   | 55/79 [00:01<00:00, 46.11it/s]
# Validation DataLoader 0:  71%|███████   | 56/79 [00:01<00:00, 46.12it/s]
# Validation DataLoader 0:  72%|███████▏  | 57/79 [00:01<00:00, 46.09it/s]
# Validation DataLoader 0:  73%|███████▎  | 58/79 [00:01<00:00, 46.10it/s]
# Validation DataLoader 0:  75%|███████▍  | 59/79 [00:01<00:00, 46.07it/s]
# Validation DataLoader 0:  76%|███████▌  | 60/79 [00:01<00:00, 46.07it/s]
# Validation DataLoader 0:  77%|███████▋  | 61/79 [00:01<00:00, 46.06it/s]
# Validation DataLoader 0:  78%|███████▊  | 62/79 [00:01<00:00, 46.05it/s]
# Validation DataLoader 0:  80%|███████▉  | 63/79 [00:01<00:00, 46.02it/s]
# Validation DataLoader 0:  81%|████████  | 64/79 [00:01<00:00, 46.02it/s]
# Validation DataLoader 0:  82%|████████▏ | 65/79 [00:01<00:00, 45.99it/s]
# Validation DataLoader 0:  84%|████████▎ | 66/79 [00:01<00:00, 45.99it/s]
# Validation DataLoader 0:  85%|████████▍ | 67/79 [00:01<00:00, 45.96it/s]
# Validation DataLoader 0:  86%|████████▌ | 68/79 [00:01<00:00, 45.97it/s]
# Validation DataLoader 0:  87%|████████▋ | 69/79 [00:01<00:00, 45.93it/s]
# Validation DataLoader 0:  89%|████████▊ | 70/79 [00:01<00:00, 45.94it/s]
# Validation DataLoader 0:  90%|████████▉ | 71/79 [00:01<00:00, 45.91it/s]
# Validation DataLoader 0:  91%|█████████ | 72/79 [00:01<00:00, 45.92it/s]
# Validation DataLoader 0:  92%|█████████▏| 73/79 [00:01<00:00, 45.90it/s]
# Validation DataLoader 0:  94%|█████████▎| 74/79 [00:01<00:00, 45.91it/s]
# Validation DataLoader 0:  95%|█████████▍| 75/79 [00:01<00:00, 45.88it/s]
# Validation DataLoader 0:  96%|█████████▌| 76/79 [00:01<00:00, 45.90it/s]
# Validation DataLoader 0:  97%|█████████▋| 77/79 [00:01<00:00, 45.88it/s]
# Validation DataLoader 0:  99%|█████████▊| 78/79 [00:01<00:00, 46.04it/s]
# Validation DataLoader 0: 100%|██████████| 79/79 [00:01<00:00, 46.49it/s]
# Epoch 3: 100%|██████████| 391/391 [00:12<00:00, 32.37it/s, train_loss=1.030, train_acc=0.650, val_loss=0.864, val_acc=0.697]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏         | 1/79 [00:00<00:01, 70.60it/s]
# Validation DataLoader 0:   3%|▎         | 2/79 [00:00<00:01, 65.02it/s]
# Validation DataLoader 0:   4%|▍         | 3/79 [00:00<00:01, 66.17it/s]
# Validation DataLoader 0:   5%|▌         | 4/79 [00:00<00:01, 58.04it/s]
# Validation DataLoader 0:   6%|▋         | 5/79 [00:00<00:01, 64.68it/s]
# Validation DataLoader 0:   8%|▊         | 6/79 [00:00<00:01, 55.31it/s]
# Validation DataLoader 0:   9%|▉         | 7/79 [00:00<00:01, 59.01it/s]
# Validation DataLoader 0:  10%|█         | 8/79 [00:00<00:01, 51.98it/s]
# Validation DataLoader 0:  11%|█▏        | 9/79 [00:00<00:01, 55.32it/s]
# Validation DataLoader 0:  13%|█▎        | 10/79 [00:00<00:01, 50.49it/s]
# Validation DataLoader 0:  14%|█▍        | 11/79 [00:00<00:01, 52.88it/s]
# Validation DataLoader 0:  15%|█▌        | 12/79 [00:00<00:01, 49.57it/s]
# Validation DataLoader 0:  16%|█▋        | 13/79 [00:00<00:01, 51.60it/s]
# Validation DataLoader 0:  18%|█▊        | 14/79 [00:00<00:01, 48.93it/s]
# Validation DataLoader 0:  19%|█▉        | 15/79 [00:00<00:01, 50.80it/s]
# Validation DataLoader 0:  20%|██        | 16/79 [00:00<00:01, 48.52it/s]
# Validation DataLoader 0:  22%|██▏       | 17/79 [00:00<00:01, 50.12it/s]
# Validation DataLoader 0:  23%|██▎       | 18/79 [00:00<00:01, 48.20it/s]
# Validation DataLoader 0:  24%|██▍       | 19/79 [00:00<00:01, 49.64it/s]
# Validation DataLoader 0:  25%|██▌       | 20/79 [00:00<00:01, 47.90it/s]
# Validation DataLoader 0:  27%|██▋       | 21/79 [00:00<00:01, 49.20it/s]
# Validation DataLoader 0:  28%|██▊       | 22/79 [00:00<00:01, 47.72it/s]
# Validation DataLoader 0:  29%|██▉       | 23/79 [00:00<00:01, 48.87it/s]
# Validation DataLoader 0:  30%|███       | 24/79 [00:00<00:01, 47.31it/s]
# Validation DataLoader 0:  32%|███▏      | 25/79 [00:00<00:01, 48.24it/s]
# Validation DataLoader 0:  33%|███▎      | 26/79 [00:00<00:01, 48.19it/s]
# Validation DataLoader 0:  34%|███▍      | 27/79 [00:00<00:01, 48.89it/s]
# Validation DataLoader 0:  35%|███▌      | 28/79 [00:00<00:01, 48.82it/s]
# Validation DataLoader 0:  37%|███▋      | 29/79 [00:00<00:01, 49.58it/s]
# Validation DataLoader 0:  38%|███▊      | 30/79 [00:00<00:00, 49.46it/s]
# Validation DataLoader 0:  39%|███▉      | 31/79 [00:00<00:00, 50.13it/s]
# Validation DataLoader 0:  41%|████      | 32/79 [00:00<00:00, 49.99it/s]
# Validation DataLoader 0:  42%|████▏     | 33/79 [00:00<00:00, 50.62it/s]
# Validation DataLoader 0:  43%|████▎     | 34/79 [00:00<00:00, 50.43it/s]
# Validation DataLoader 0:  44%|████▍     | 35/79 [00:00<00:00, 51.12it/s]
# Validation DataLoader 0:  46%|████▌     | 36/79 [00:00<00:00, 51.11it/s]
# Validation DataLoader 0:  47%|████▋     | 37/79 [00:00<00:00, 51.27it/s]
# Validation DataLoader 0:  48%|████▊     | 38/79 [00:00<00:00, 51.47it/s]
# Validation DataLoader 0:  49%|████▉     | 39/79 [00:00<00:00, 51.66it/s]
# Validation DataLoader 0:  51%|█████     | 40/79 [00:00<00:00, 51.85it/s]
# Validation DataLoader 0:  52%|█████▏    | 41/79 [00:00<00:00, 52.02it/s]
# Validation DataLoader 0:  53%|█████▎    | 42/79 [00:00<00:00, 52.20it/s]
# Validation DataLoader 0:  54%|█████▍    | 43/79 [00:00<00:00, 52.29it/s]
# Validation DataLoader 0:  56%|█████▌    | 44/79 [00:00<00:00, 52.37it/s]
# Validation DataLoader 0:  57%|█████▋    | 45/79 [00:00<00:00, 52.70it/s]
# Validation DataLoader 0:  58%|█████▊    | 46/79 [00:00<00:00, 52.65it/s]
# Validation DataLoader 0:  59%|█████▉    | 47/79 [00:00<00:00, 52.92it/s]
# Validation DataLoader 0:  61%|██████    | 48/79 [00:00<00:00, 52.89it/s]
# Validation DataLoader 0:  62%|██████▏   | 49/79 [00:00<00:00, 53.20it/s]
# Validation DataLoader 0:  63%|██████▎   | 50/79 [00:00<00:00, 53.06it/s]
# Validation DataLoader 0:  65%|██████▍   | 51/79 [00:00<00:00, 53.49it/s]
# Validation DataLoader 0:  66%|██████▌   | 52/79 [00:00<00:00, 53.30it/s]
# Validation DataLoader 0:  67%|██████▋   | 53/79 [00:00<00:00, 53.86it/s]
# Validation DataLoader 0:  68%|██████▊   | 54/79 [00:01<00:00, 52.98it/s]
# Validation DataLoader 0:  70%|██████▉   | 55/79 [00:01<00:00, 53.16it/s]
# Validation DataLoader 0:  71%|███████   | 56/79 [00:01<00:00, 52.73it/s]
# Validation DataLoader 0:  72%|███████▏  | 57/79 [00:01<00:00, 53.01it/s]
# Validation DataLoader 0:  73%|███████▎  | 58/79 [00:01<00:00, 52.43it/s]
# Validation DataLoader 0:  75%|███████▍  | 59/79 [00:01<00:00, 52.73it/s]
# Validation DataLoader 0:  76%|███████▌  | 60/79 [00:01<00:00, 52.09it/s]
# Validation DataLoader 0:  77%|███████▋  | 61/79 [00:01<00:00, 52.38it/s]
# Validation DataLoader 0:  78%|███████▊  | 62/79 [00:01<00:00, 52.29it/s]
# Validation DataLoader 0:  80%|███████▉  | 63/79 [00:01<00:00, 52.58it/s]
# Validation DataLoader 0:  81%|████████  | 64/79 [00:01<00:00, 52.06it/s]
# Validation DataLoader 0:  82%|████████▏ | 65/79 [00:01<00:00, 52.34it/s]
# Validation DataLoader 0:  84%|████████▎ | 66/79 [00:01<00:00, 51.85it/s]
# Validation DataLoader 0:  85%|████████▍ | 67/79 [00:01<00:00, 52.13it/s]
# Validation DataLoader 0:  86%|████████▌ | 68/79 [00:01<00:00, 51.65it/s]
# Validation DataLoader 0:  87%|████████▋ | 69/79 [00:01<00:00, 51.92it/s]
# Validation DataLoader 0:  89%|████████▊ | 70/79 [00:01<00:00, 51.46it/s]
# Validation DataLoader 0:  90%|████████▉ | 71/79 [00:01<00:00, 51.72it/s]
# Validation DataLoader 0:  91%|█████████ | 72/79 [00:01<00:00, 51.27it/s]
# Validation DataLoader 0:  92%|█████████▏| 73/79 [00:01<00:00, 51.54it/s]
# Validation DataLoader 0:  94%|█████████▎| 74/79 [00:01<00:00, 51.11it/s]
# Validation DataLoader 0:  95%|█████████▍| 75/79 [00:01<00:00, 51.35it/s]
# Validation DataLoader 0:  96%|█████████▌| 76/79 [00:01<00:00, 50.96it/s]
# Validation DataLoader 0:  97%|█████████▋| 77/79 [00:01<00:00, 51.04it/s]
# Validation DataLoader 0:  99%|█████████▊| 78/79 [00:01<00:00, 51.04it/s]
# Validation DataLoader 0: 100%|██████████| 79/79 [00:01<00:00, 51.52it/s]
# Epoch 4: 100%|██████████| 391/391 [00:12<00:00, 32.32it/s, train_loss=0.832, train_acc=0.725, val_loss=0.788, val_acc=0.728]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏         | 1/79 [00:00<00:01, 72.56it/s]
# Validation DataLoader 0:   3%|▎         | 2/79 [00:00<00:01, 45.87it/s]
# Validation DataLoader 0:   4%|▍         | 3/79 [00:00<00:01, 58.97it/s]
# Validation DataLoader 0:   5%|▌         | 4/79 [00:00<00:01, 45.25it/s]
# Validation DataLoader 0:   6%|▋         | 5/79 [00:00<00:01, 52.24it/s]
# Validation DataLoader 0:   8%|▊         | 6/79 [00:00<00:01, 45.22it/s]
# Validation DataLoader 0:   9%|▉         | 7/79 [00:00<00:01, 50.04it/s]
# Validation DataLoader 0:  10%|█         | 8/79 [00:00<00:01, 45.31it/s]
# Validation DataLoader 0:  11%|█▏        | 9/79 [00:00<00:01, 48.98it/s]
# Validation DataLoader 0:  13%|█▎        | 10/79 [00:00<00:01, 45.38it/s]
# Validation DataLoader 0:  14%|█▍        | 11/79 [00:00<00:01, 48.35it/s]
# Validation DataLoader 0:  15%|█▌        | 12/79 [00:00<00:01, 45.39it/s]
# Validation DataLoader 0:  16%|█▋        | 13/79 [00:00<00:01, 47.85it/s]
# Validation DataLoader 0:  18%|█▊        | 14/79 [00:00<00:01, 45.36it/s]
# Validation DataLoader 0:  19%|█▉        | 15/79 [00:00<00:01, 47.49it/s]
# Validation DataLoader 0:  20%|██        | 16/79 [00:00<00:01, 45.37it/s]
# Validation DataLoader 0:  22%|██▏       | 17/79 [00:00<00:01, 47.23it/s]
# Validation DataLoader 0:  23%|██▎       | 18/79 [00:00<00:01, 45.38it/s]
# Validation DataLoader 0:  24%|██▍       | 19/79 [00:00<00:01, 47.04it/s]
# Validation DataLoader 0:  25%|██▌       | 20/79 [00:00<00:01, 45.39it/s]
# Validation DataLoader 0:  27%|██▋       | 21/79 [00:00<00:01, 46.89it/s]
# Validation DataLoader 0:  28%|██▊       | 22/79 [00:00<00:01, 45.37it/s]
# Validation DataLoader 0:  29%|██▉       | 23/79 [00:00<00:01, 46.74it/s]
# Validation DataLoader 0:  30%|███       | 24/79 [00:00<00:01, 45.37it/s]
# Validation DataLoader 0:  32%|███▏      | 25/79 [00:00<00:01, 46.61it/s]
# Validation DataLoader 0:  33%|███▎      | 26/79 [00:00<00:01, 45.36it/s]
# Validation DataLoader 0:  34%|███▍      | 27/79 [00:00<00:01, 46.52it/s]
# Validation DataLoader 0:  35%|███▌      | 28/79 [00:00<00:01, 45.36it/s]
# Validation DataLoader 0:  37%|███▋      | 29/79 [00:00<00:01, 46.44it/s]
# Validation DataLoader 0:  38%|███▊      | 30/79 [00:00<00:01, 45.34it/s]
# Validation DataLoader 0:  39%|███▉      | 31/79 [00:00<00:01, 46.34it/s]
# Validation DataLoader 0:  41%|████      | 32/79 [00:00<00:01, 45.33it/s]
# Validation DataLoader 0:  42%|████▏     | 33/79 [00:00<00:00, 46.26it/s]
# Validation DataLoader 0:  43%|████▎     | 34/79 [00:00<00:00, 45.28it/s]
# Validation DataLoader 0:  44%|████▍     | 35/79 [00:00<00:00, 46.14it/s]
# Validation DataLoader 0:  46%|████▌     | 36/79 [00:00<00:00, 45.26it/s]
# Validation DataLoader 0:  47%|████▋     | 37/79 [00:00<00:00, 46.01it/s]
# Validation DataLoader 0:  48%|████▊     | 38/79 [00:00<00:00, 45.22it/s]
# Validation DataLoader 0:  49%|████▉     | 39/79 [00:00<00:00, 45.99it/s]
# Validation DataLoader 0:  51%|█████     | 40/79 [00:00<00:00, 45.19it/s]
# Validation DataLoader 0:  52%|█████▏    | 41/79 [00:00<00:00, 45.92it/s]
# Validation DataLoader 0:  53%|█████▎    | 42/79 [00:00<00:00, 45.04it/s]
# Validation DataLoader 0:  54%|█████▍    | 43/79 [00:00<00:00, 45.62it/s]
# Validation DataLoader 0:  56%|█████▌    | 44/79 [00:00<00:00, 45.53it/s]
# Validation DataLoader 0:  57%|█████▋    | 45/79 [00:00<00:00, 46.08it/s]
# Validation DataLoader 0:  58%|█████▊    | 46/79 [00:01<00:00, 45.99it/s]
# Validation DataLoader 0:  59%|█████▉    | 47/79 [00:01<00:00, 46.54it/s]
# Validation DataLoader 0:  61%|██████    | 48/79 [00:01<00:00, 46.51it/s]
# Validation DataLoader 0:  62%|██████▏   | 49/79 [00:01<00:00, 47.15it/s]
# Validation DataLoader 0:  63%|██████▎   | 50/79 [00:01<00:00, 46.44it/s]
# Validation DataLoader 0:  65%|██████▍   | 51/79 [00:01<00:00, 47.05it/s]
# Validation DataLoader 0:  66%|██████▌   | 52/79 [00:01<00:00, 46.42it/s]
# Validation DataLoader 0:  67%|██████▋   | 53/79 [00:01<00:00, 46.96it/s]
# Validation DataLoader 0:  68%|██████▊   | 54/79 [00:01<00:00, 46.35it/s]
# Validation DataLoader 0:  70%|██████▉   | 55/79 [00:01<00:00, 46.87it/s]
# Validation DataLoader 0:  71%|███████   | 56/79 [00:01<00:00, 46.29it/s]
# Validation DataLoader 0:  72%|███████▏  | 57/79 [00:01<00:00, 46.79it/s]
# Validation DataLoader 0:  73%|███████▎  | 58/79 [00:01<00:00, 46.26it/s]
# Validation DataLoader 0:  75%|███████▍  | 59/79 [00:01<00:00, 46.74it/s]
# Validation DataLoader 0:  76%|███████▌  | 60/79 [00:01<00:00, 46.22it/s]
# Validation DataLoader 0:  77%|███████▋  | 61/79 [00:01<00:00, 46.68it/s]
# Validation DataLoader 0:  78%|███████▊  | 62/79 [00:01<00:00, 46.18it/s]
# Validation DataLoader 0:  80%|███████▉  | 63/79 [00:01<00:00, 46.55it/s]
# Validation DataLoader 0:  81%|████████  | 64/79 [00:01<00:00, 46.35it/s]
# Validation DataLoader 0:  82%|████████▏ | 65/79 [00:01<00:00, 46.75it/s]
# Validation DataLoader 0:  84%|████████▎ | 66/79 [00:01<00:00, 46.67it/s]
# Validation DataLoader 0:  85%|████████▍ | 67/79 [00:01<00:00, 47.06it/s]
# Validation DataLoader 0:  86%|████████▌ | 68/79 [00:01<00:00, 46.87it/s]
# Validation DataLoader 0:  87%|████████▋ | 69/79 [00:01<00:00, 47.25it/s]
# Validation DataLoader 0:  89%|████████▊ | 70/79 [00:01<00:00, 46.85it/s]
# Validation DataLoader 0:  90%|████████▉ | 71/79 [00:01<00:00, 47.28it/s]
# Validation DataLoader 0:  91%|█████████ | 72/79 [00:01<00:00, 46.78it/s]
# Validation DataLoader 0:  92%|█████████▏| 73/79 [00:01<00:00, 47.18it/s]
# Validation DataLoader 0:  94%|█████████▎| 74/79 [00:01<00:00, 46.74it/s]
# Validation DataLoader 0:  95%|█████████▍| 75/79 [00:01<00:00, 47.16it/s]
# Validation DataLoader 0:  96%|█████████▌| 76/79 [00:01<00:00, 46.91it/s]
# Validation DataLoader 0:  97%|█████████▋| 77/79 [00:01<00:00, 47.32it/s]
# Validation DataLoader 0:  99%|█████████▊| 78/79 [00:01<00:00, 47.31it/s]
# Validation DataLoader 0: 100%|██████████| 79/79 [00:01<00:00, 47.77it/s]
# Epoch 5: 100%|██████████| 391/391 [00:12<00:00, 32.20it/s, train_loss=0.688, train_acc=0.788, val_loss=0.758, val_acc=0.744]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏         | 1/79 [00:00<00:01, 72.34it/s]
# Validation DataLoader 0:   3%|▎         | 2/79 [00:00<00:01, 59.12it/s]
# Validation DataLoader 0:   4%|▍         | 3/79 [00:00<00:01, 71.22it/s]
# Validation DataLoader 0:   5%|▌         | 4/79 [00:00<00:01, 51.35it/s]
# Validation DataLoader 0:   6%|▋         | 5/79 [00:00<00:01, 58.03it/s]
# Validation DataLoader 0:   8%|▊         | 6/79 [00:00<00:01, 49.10it/s]
# Validation DataLoader 0:   9%|▉         | 7/79 [00:00<00:01, 53.56it/s]
# Validation DataLoader 0:  10%|█         | 8/79 [00:00<00:01, 47.89it/s]
# Validation DataLoader 0:  11%|█▏        | 9/79 [00:00<00:01, 51.27it/s]
# Validation DataLoader 0:  13%|█▎        | 10/79 [00:00<00:01, 47.11it/s]
# Validation DataLoader 0:  14%|█▍        | 11/79 [00:00<00:01, 49.80it/s]
# Validation DataLoader 0:  15%|█▌        | 12/79 [00:00<00:01, 46.82it/s]
# Validation DataLoader 0:  16%|█▋        | 13/79 [00:00<00:01, 49.14it/s]
# Validation DataLoader 0:  18%|█▊        | 14/79 [00:00<00:01, 46.61it/s]
# Validation DataLoader 0:  19%|█▉        | 15/79 [00:00<00:01, 48.60it/s]
# Validation DataLoader 0:  20%|██        | 16/79 [00:00<00:01, 46.41it/s]
# Validation DataLoader 0:  22%|██▏       | 17/79 [00:00<00:01, 48.12it/s]
# Validation DataLoader 0:  23%|██▎       | 18/79 [00:00<00:01, 46.29it/s]
# Validation DataLoader 0:  24%|██▍       | 19/79 [00:00<00:01, 47.83it/s]
# Validation DataLoader 0:  25%|██▌       | 20/79 [00:00<00:01, 46.21it/s]
# Validation DataLoader 0:  27%|██▋       | 21/79 [00:00<00:01, 47.58it/s]
# Validation DataLoader 0:  28%|██▊       | 22/79 [00:00<00:01, 46.12it/s]
# Validation DataLoader 0:  29%|██▉       | 23/79 [00:00<00:01, 47.39it/s]
# Validation DataLoader 0:  30%|███       | 24/79 [00:00<00:01, 46.06it/s]
# Validation DataLoader 0:  32%|███▏      | 25/79 [00:00<00:01, 47.22it/s]
# Validation DataLoader 0:  33%|███▎      | 26/79 [00:00<00:01, 46.00it/s]
# Validation DataLoader 0:  34%|███▍      | 27/79 [00:00<00:01, 47.06it/s]
# Validation DataLoader 0:  35%|███▌      | 28/79 [00:00<00:01, 45.88it/s]
# Validation DataLoader 0:  37%|███▋      | 29/79 [00:00<00:01, 46.87it/s]
# Validation DataLoader 0:  38%|███▊      | 30/79 [00:00<00:01, 45.85it/s]
# Validation DataLoader 0:  39%|███▉      | 31/79 [00:00<00:01, 46.78it/s]
# Validation DataLoader 0:  41%|████      | 32/79 [00:00<00:01, 45.83it/s]
# Validation DataLoader 0:  42%|████▏     | 33/79 [00:00<00:00, 46.69it/s]
# Validation DataLoader 0:  43%|████▎     | 34/79 [00:00<00:00, 45.79it/s]
# Validation DataLoader 0:  44%|████▍     | 35/79 [00:00<00:00, 46.60it/s]
# Validation DataLoader 0:  46%|████▌     | 36/79 [00:00<00:00, 45.75it/s]
# Validation DataLoader 0:  47%|████▋     | 37/79 [00:00<00:00, 46.54it/s]
# Validation DataLoader 0:  48%|████▊     | 38/79 [00:00<00:00, 45.73it/s]
# Validation DataLoader 0:  49%|████▉     | 39/79 [00:00<00:00, 46.46it/s]
# Validation DataLoader 0:  51%|█████     | 40/79 [00:00<00:00, 45.70it/s]
# Validation DataLoader 0:  52%|█████▏    | 41/79 [00:00<00:00, 46.38it/s]
# Validation DataLoader 0:  53%|█████▎    | 42/79 [00:00<00:00, 45.68it/s]
# Validation DataLoader 0:  54%|█████▍    | 43/79 [00:00<00:00, 46.32it/s]
# Validation DataLoader 0:  56%|█████▌    | 44/79 [00:00<00:00, 45.66it/s]
# Validation DataLoader 0:  57%|█████▋    | 45/79 [00:00<00:00, 46.28it/s]
# Validation DataLoader 0:  58%|█████▊    | 46/79 [00:01<00:00, 45.64it/s]
# Validation DataLoader 0:  59%|█████▉    | 47/79 [00:01<00:00, 46.24it/s]
# Validation DataLoader 0:  61%|██████    | 48/79 [00:01<00:00, 45.64it/s]
# Validation DataLoader 0:  62%|██████▏   | 49/79 [00:01<00:00, 46.21it/s]
# Validation DataLoader 0:  63%|██████▎   | 50/79 [00:01<00:00, 45.65it/s]
# Validation DataLoader 0:  65%|██████▍   | 51/79 [00:01<00:00, 46.20it/s]
# Validation DataLoader 0:  66%|██████▌   | 52/79 [00:01<00:00, 45.64it/s]
# Validation DataLoader 0:  67%|██████▋   | 53/79 [00:01<00:00, 46.18it/s]
# Validation DataLoader 0:  68%|██████▊   | 54/79 [00:01<00:00, 45.63it/s]
# Validation DataLoader 0:  70%|██████▉   | 55/79 [00:01<00:00, 46.15it/s]
# Validation DataLoader 0:  71%|███████   | 56/79 [00:01<00:00, 45.63it/s]
# Validation DataLoader 0:  72%|███████▏  | 57/79 [00:01<00:00, 46.14it/s]
# Validation DataLoader 0:  73%|███████▎  | 58/79 [00:01<00:00, 45.60it/s]
# Validation DataLoader 0:  75%|███████▍  | 59/79 [00:01<00:00, 46.08it/s]
# Validation DataLoader 0:  76%|███████▌  | 60/79 [00:01<00:00, 45.59it/s]
# Validation DataLoader 0:  77%|███████▋  | 61/79 [00:01<00:00, 46.05it/s]
# Validation DataLoader 0:  78%|███████▊  | 62/79 [00:01<00:00, 45.60it/s]
# Validation DataLoader 0:  80%|███████▉  | 63/79 [00:01<00:00, 46.05it/s]
# Validation DataLoader 0:  81%|████████  | 64/79 [00:01<00:00, 45.58it/s]
# Validation DataLoader 0:  82%|████████▏ | 65/79 [00:01<00:00, 46.02it/s]
# Validation DataLoader 0:  84%|████████▎ | 66/79 [00:01<00:00, 45.55it/s]
# Validation DataLoader 0:  85%|████████▍ | 67/79 [00:01<00:00, 45.86it/s]
# Validation DataLoader 0:  86%|████████▌ | 68/79 [00:01<00:00, 45.56it/s]
# Validation DataLoader 0:  87%|████████▋ | 69/79 [00:01<00:00, 45.96it/s]
# Validation DataLoader 0:  89%|████████▊ | 70/79 [00:01<00:00, 45.56it/s]
# Validation DataLoader 0:  90%|████████▉ | 71/79 [00:01<00:00, 45.89it/s]
# Validation DataLoader 0:  91%|█████████ | 72/79 [00:01<00:00, 45.74it/s]
# Validation DataLoader 0:  92%|█████████▏| 73/79 [00:01<00:00, 46.02it/s]
# Validation DataLoader 0:  94%|█████████▎| 74/79 [00:01<00:00, 46.06it/s]
# Validation DataLoader 0:  95%|█████████▍| 75/79 [00:01<00:00, 46.43it/s]
# Validation DataLoader 0:  96%|█████████▌| 76/79 [00:01<00:00, 46.26it/s]
# Validation DataLoader 0:  97%|█████████▋| 77/79 [00:01<00:00, 46.59it/s]
# Validation DataLoader 0:  99%|█████████▊| 78/79 [00:01<00:00, 46.57it/s]
# Validation DataLoader 0: 100%|██████████| 79/79 [00:01<00:00, 47.02it/s]
# Epoch 6: 100%|██████████| 391/391 [00:12<00:00, 30.56it/s, train_loss=0.646, train_acc=0.788, val_loss=0.707, val_acc=0.754]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏         | 1/79 [00:00<00:01, 67.69it/s]
# Validation DataLoader 0:   3%|▎         | 2/79 [00:00<00:01, 50.78it/s]
# Validation DataLoader 0:   4%|▍         | 3/79 [00:00<00:01, 60.54it/s]
# Validation DataLoader 0:   5%|▌         | 4/79 [00:00<00:01, 57.24it/s]
# Validation DataLoader 0:   6%|▋         | 5/79 [00:00<00:01, 61.36it/s]
# Validation DataLoader 0:   8%|▊         | 6/79 [00:00<00:01, 58.68it/s]
# Validation DataLoader 0:   9%|▉         | 7/79 [00:00<00:01, 63.28it/s]
# Validation DataLoader 0:  10%|█         | 8/79 [00:00<00:01, 54.47it/s]
# Validation DataLoader 0:  11%|█▏        | 9/79 [00:00<00:01, 57.98it/s]
# Validation DataLoader 0:  13%|█▎        | 10/79 [00:00<00:01, 52.16it/s]
# Validation DataLoader 0:  14%|█▍        | 11/79 [00:00<00:01, 54.88it/s]
# Validation DataLoader 0:  15%|█▌        | 12/79 [00:00<00:01, 50.81it/s]
# Validation DataLoader 0:  16%|█▋        | 13/79 [00:00<00:01, 53.09it/s]
# Validation DataLoader 0:  18%|█▊        | 14/79 [00:00<00:01, 49.81it/s]
# Validation DataLoader 0:  19%|█▉        | 15/79 [00:00<00:01, 51.76it/s]
# Validation DataLoader 0:  20%|██        | 16/79 [00:00<00:01, 49.09it/s]
# Validation DataLoader 0:  22%|██▏       | 17/79 [00:00<00:01, 50.84it/s]
# Validation DataLoader 0:  23%|██▎       | 18/79 [00:00<00:01, 48.65it/s]
# Validation DataLoader 0:  24%|██▍       | 19/79 [00:00<00:01, 50.17it/s]
# Validation DataLoader 0:  25%|██▌       | 20/79 [00:00<00:01, 48.32it/s]
# Validation DataLoader 0:  27%|██▋       | 21/79 [00:00<00:01, 49.55it/s]
# Validation DataLoader 0:  28%|██▊       | 22/79 [00:00<00:01, 47.99it/s]
# Validation DataLoader 0:  29%|██▉       | 23/79 [00:00<00:01, 49.24it/s]
# Validation DataLoader 0:  30%|███       | 24/79 [00:00<00:01, 47.76it/s]
# Validation DataLoader 0:  32%|███▏      | 25/79 [00:00<00:01, 48.94it/s]
# Validation DataLoader 0:  33%|███▎      | 26/79 [00:00<00:01, 47.53it/s]
# Validation DataLoader 0:  34%|███▍      | 27/79 [00:00<00:01, 48.61it/s]
# Validation DataLoader 0:  35%|███▌      | 28/79 [00:00<00:01, 47.39it/s]
# Validation DataLoader 0:  37%|███▋      | 29/79 [00:00<00:01, 48.39it/s]
# Validation DataLoader 0:  38%|███▊      | 30/79 [00:00<00:01, 47.24it/s]
# Validation DataLoader 0:  39%|███▉      | 31/79 [00:00<00:00, 48.21it/s]
# Validation DataLoader 0:  41%|████      | 32/79 [00:00<00:00, 47.12it/s]
# Validation DataLoader 0:  42%|████▏     | 33/79 [00:00<00:00, 48.00it/s]
# Validation DataLoader 0:  43%|████▎     | 34/79 [00:00<00:00, 47.00it/s]
# Validation DataLoader 0:  44%|████▍     | 35/79 [00:00<00:00, 47.82it/s]
# Validation DataLoader 0:  46%|████▌     | 36/79 [00:00<00:00, 46.88it/s]
# Validation DataLoader 0:  47%|████▋     | 37/79 [00:00<00:00, 47.62it/s]
# Validation DataLoader 0:  48%|████▊     | 38/79 [00:00<00:00, 46.79it/s]
# Validation DataLoader 0:  49%|████▉     | 39/79 [00:00<00:00, 47.53it/s]
# Validation DataLoader 0:  51%|█████     | 40/79 [00:00<00:00, 46.75it/s]
# Validation DataLoader 0:  52%|█████▏    | 41/79 [00:00<00:00, 47.46it/s]
# Validation DataLoader 0:  53%|█████▎    | 42/79 [00:00<00:00, 46.69it/s]
# Validation DataLoader 0:  54%|█████▍    | 43/79 [00:00<00:00, 47.35it/s]
# Validation DataLoader 0:  56%|█████▌    | 44/79 [00:00<00:00, 46.63it/s]
# Validation DataLoader 0:  57%|█████▋    | 45/79 [00:00<00:00, 47.27it/s]
# Validation DataLoader 0:  58%|█████▊    | 46/79 [00:00<00:00, 46.58it/s]
# Validation DataLoader 0:  59%|█████▉    | 47/79 [00:00<00:00, 47.18it/s]
# Validation DataLoader 0:  61%|██████    | 48/79 [00:01<00:00, 46.56it/s]
# Validation DataLoader 0:  62%|██████▏   | 49/79 [00:01<00:00, 47.14it/s]
# Validation DataLoader 0:  63%|██████▎   | 50/79 [00:01<00:00, 46.53it/s]
# Validation DataLoader 0:  65%|██████▍   | 51/79 [00:01<00:00, 47.08it/s]
# Validation DataLoader 0:  66%|██████▌   | 52/79 [00:01<00:00, 46.50it/s]
# Validation DataLoader 0:  67%|██████▋   | 53/79 [00:01<00:00, 47.03it/s]
# Validation DataLoader 0:  68%|██████▊   | 54/79 [00:01<00:00, 46.44it/s]
# Validation DataLoader 0:  70%|██████▉   | 55/79 [00:01<00:00, 46.96it/s]
# Validation DataLoader 0:  71%|███████   | 56/79 [00:01<00:00, 46.39it/s]
# Validation DataLoader 0:  72%|███████▏  | 57/79 [00:01<00:00, 46.89it/s]
# Validation DataLoader 0:  73%|███████▎  | 58/79 [00:01<00:00, 46.36it/s]
# Validation DataLoader 0:  75%|███████▍  | 59/79 [00:01<00:00, 46.84it/s]
# Validation DataLoader 0:  76%|███████▌  | 60/79 [00:01<00:00, 46.21it/s]
# Validation DataLoader 0:  77%|███████▋  | 61/79 [00:01<00:00, 46.48it/s]
# Validation DataLoader 0:  78%|███████▊  | 62/79 [00:01<00:00, 46.60it/s]
# Validation DataLoader 0:  80%|███████▉  | 63/79 [00:01<00:00, 46.96it/s]
# Validation DataLoader 0:  81%|████████  | 64/79 [00:01<00:00, 46.98it/s]
# Validation DataLoader 0:  82%|████████▏ | 65/79 [00:01<00:00, 47.20it/s]
# Validation DataLoader 0:  84%|████████▎ | 66/79 [00:01<00:00, 47.32it/s]
# Validation DataLoader 0:  85%|████████▍ | 67/79 [00:01<00:00, 47.38it/s]
# Validation DataLoader 0:  86%|████████▌ | 68/79 [00:01<00:00, 47.42it/s]
# Validation DataLoader 0:  87%|████████▋ | 69/79 [00:01<00:00, 47.62it/s]
# Validation DataLoader 0:  89%|████████▊ | 70/79 [00:01<00:00, 47.75it/s]
# Validation DataLoader 0:  90%|████████▉ | 71/79 [00:01<00:00, 47.78it/s]
# Validation DataLoader 0:  91%|█████████ | 72/79 [00:01<00:00, 48.09it/s]
# Validation DataLoader 0:  92%|█████████▏| 73/79 [00:01<00:00, 48.00it/s]
# Validation DataLoader 0:  94%|█████████▎| 74/79 [00:01<00:00, 48.39it/s]
# Validation DataLoader 0:  95%|█████████▍| 75/79 [00:01<00:00, 47.93it/s]
# Validation DataLoader 0:  96%|█████████▌| 76/79 [00:01<00:00, 48.31it/s]
# Validation DataLoader 0:  97%|█████████▋| 77/79 [00:01<00:00, 47.87it/s]
# Validation DataLoader 0:  99%|█████████▊| 78/79 [00:01<00:00, 48.27it/s]
# Validation DataLoader 0: 100%|██████████| 79/79 [00:01<00:00, 48.71it/s]
# Epoch 7: 100%|██████████| 391/391 [00:11<00:00, 32.74it/s, train_loss=0.686, train_acc=0.750, val_loss=0.659, val_acc=0.772]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏         | 1/79 [00:00<00:01, 70.30it/s]
# Validation DataLoader 0:   3%|▎         | 2/79 [00:00<00:01, 55.34it/s]
# Validation DataLoader 0:   4%|▍         | 3/79 [00:00<00:01, 64.09it/s]
# Validation DataLoader 0:   5%|▌         | 4/79 [00:00<00:01, 56.09it/s]
# Validation DataLoader 0:   6%|▋         | 5/79 [00:00<00:01, 60.67it/s]
# Validation DataLoader 0:   8%|▊         | 6/79 [00:00<00:01, 55.28it/s]
# Validation DataLoader 0:   9%|▉         | 7/79 [00:00<00:01, 59.21it/s]
# Validation DataLoader 0:  10%|█         | 8/79 [00:00<00:01, 56.34it/s]
# Validation DataLoader 0:  11%|█▏        | 9/79 [00:00<00:01, 59.24it/s]
# Validation DataLoader 0:  13%|█▎        | 10/79 [00:00<00:01, 55.89it/s]
# Validation DataLoader 0:  14%|█▍        | 11/79 [00:00<00:01, 57.80it/s]
# Validation DataLoader 0:  15%|█▌        | 12/79 [00:00<00:01, 54.66it/s]
# Validation DataLoader 0:  16%|█▋        | 13/79 [00:00<00:01, 57.37it/s]
# Validation DataLoader 0:  18%|█▊        | 14/79 [00:00<00:01, 54.26it/s]
# Validation DataLoader 0:  19%|█▉        | 15/79 [00:00<00:01, 56.09it/s]
# Validation DataLoader 0:  20%|██        | 16/79 [00:00<00:01, 55.03it/s]
# Validation DataLoader 0:  22%|██▏       | 17/79 [00:00<00:01, 56.35it/s]
# Validation DataLoader 0:  23%|██▎       | 18/79 [00:00<00:01, 54.58it/s]
# Validation DataLoader 0:  24%|██▍       | 19/79 [00:00<00:01, 55.70it/s]
# Validation DataLoader 0:  25%|██▌       | 20/79 [00:00<00:01, 53.58it/s]
# Validation DataLoader 0:  27%|██▋       | 21/79 [00:00<00:01, 55.17it/s]
# Validation DataLoader 0:  28%|██▊       | 22/79 [00:00<00:01, 52.71it/s]
# Validation DataLoader 0:  29%|██▉       | 23/79 [00:00<00:01, 54.16it/s]
# Validation DataLoader 0:  30%|███       | 24/79 [00:00<00:01, 52.05it/s]
# Validation DataLoader 0:  32%|███▏      | 25/79 [00:00<00:01, 53.34it/s]
# Validation DataLoader 0:  33%|███▎      | 26/79 [00:00<00:01, 51.40it/s]
# Validation DataLoader 0:  34%|███▍      | 27/79 [00:00<00:00, 52.61it/s]
# Validation DataLoader 0:  35%|███▌      | 28/79 [00:00<00:01, 50.90it/s]
# Validation DataLoader 0:  37%|███▋      | 29/79 [00:00<00:00, 52.02it/s]
# Validation DataLoader 0:  38%|███▊      | 30/79 [00:00<00:00, 50.41it/s]
# Validation DataLoader 0:  39%|███▉      | 31/79 [00:00<00:00, 51.43it/s]
# Validation DataLoader 0:  41%|████      | 32/79 [00:00<00:00, 50.07it/s]
# Validation DataLoader 0:  42%|████▏     | 33/79 [00:00<00:00, 51.05it/s]
# Validation DataLoader 0:  43%|████▎     | 34/79 [00:00<00:00, 49.78it/s]
# Validation DataLoader 0:  44%|████▍     | 35/79 [00:00<00:00, 50.71it/s]
# Validation DataLoader 0:  46%|████▌     | 36/79 [00:00<00:00, 49.52it/s]
# Validation DataLoader 0:  47%|████▋     | 37/79 [00:00<00:00, 50.38it/s]
# Validation DataLoader 0:  48%|████▊     | 38/79 [00:00<00:00, 49.27it/s]
# Validation DataLoader 0:  49%|████▉     | 39/79 [00:00<00:00, 49.95it/s]
# Validation DataLoader 0:  51%|█████     | 40/79 [00:00<00:00, 49.08it/s]
# Validation DataLoader 0:  52%|█████▏    | 41/79 [00:00<00:00, 49.87it/s]
# Validation DataLoader 0:  53%|█████▎    | 42/79 [00:00<00:00, 48.91it/s]
# Validation DataLoader 0:  54%|█████▍    | 43/79 [00:00<00:00, 49.67it/s]
# Validation DataLoader 0:  56%|█████▌    | 44/79 [00:00<00:00, 48.73it/s]
# Validation DataLoader 0:  57%|█████▋    | 45/79 [00:00<00:00, 49.44it/s]
# Validation DataLoader 0:  58%|█████▊    | 46/79 [00:00<00:00, 48.58it/s]
# Validation DataLoader 0:  59%|█████▉    | 47/79 [00:00<00:00, 49.26it/s]
# Validation DataLoader 0:  61%|██████    | 48/79 [00:00<00:00, 48.44it/s]
# Validation DataLoader 0:  62%|██████▏   | 49/79 [00:00<00:00, 49.10it/s]
# Validation DataLoader 0:  63%|██████▎   | 50/79 [00:01<00:00, 48.31it/s]
# Validation DataLoader 0:  65%|██████▍   | 51/79 [00:01<00:00, 48.95it/s]
# Validation DataLoader 0:  66%|██████▌   | 52/79 [00:01<00:00, 48.20it/s]
# Validation DataLoader 0:  67%|██████▋   | 53/79 [00:01<00:00, 48.80it/s]
# Validation DataLoader 0:  68%|██████▊   | 54/79 [00:01<00:00, 48.09it/s]
# Validation DataLoader 0:  70%|██████▉   | 55/79 [00:01<00:00, 48.67it/s]
# Validation DataLoader 0:  71%|███████   | 56/79 [00:01<00:00, 47.99it/s]
# Validation DataLoader 0:  72%|███████▏  | 57/79 [00:01<00:00, 48.54it/s]
# Validation DataLoader 0:  73%|███████▎  | 58/79 [00:01<00:00, 47.90it/s]
# Validation DataLoader 0:  75%|███████▍  | 59/79 [00:01<00:00, 48.44it/s]
# Validation DataLoader 0:  76%|███████▌  | 60/79 [00:01<00:00, 47.80it/s]
# Validation DataLoader 0:  77%|███████▋  | 61/79 [00:01<00:00, 48.32it/s]
# Validation DataLoader 0:  78%|███████▊  | 62/79 [00:01<00:00, 47.99it/s]
# Validation DataLoader 0:  80%|███████▉  | 63/79 [00:01<00:00, 48.40it/s]
# Validation DataLoader 0:  81%|████████  | 64/79 [00:01<00:00, 48.35it/s]
# Validation DataLoader 0:  82%|████████▏ | 65/79 [00:01<00:00, 48.85it/s]
# Validation DataLoader 0:  84%|████████▎ | 66/79 [00:01<00:00, 48.28it/s]
# Validation DataLoader 0:  85%|████████▍ | 67/79 [00:01<00:00, 48.75it/s]
# Validation DataLoader 0:  86%|████████▌ | 68/79 [00:01<00:00, 48.19it/s]
# Validation DataLoader 0:  87%|████████▋ | 69/79 [00:01<00:00, 48.66it/s]
# Validation DataLoader 0:  89%|████████▊ | 70/79 [00:01<00:00, 48.13it/s]
# Validation DataLoader 0:  90%|████████▉ | 71/79 [00:01<00:00, 48.58it/s]
# Validation DataLoader 0:  91%|█████████ | 72/79 [00:01<00:00, 48.05it/s]
# Validation DataLoader 0:  92%|█████████▏| 73/79 [00:01<00:00, 48.49it/s]
# Validation DataLoader 0:  94%|█████████▎| 74/79 [00:01<00:00, 47.98it/s]
# Validation DataLoader 0:  95%|█████████▍| 75/79 [00:01<00:00, 48.40it/s]
# Validation DataLoader 0:  96%|█████████▌| 76/79 [00:01<00:00, 48.07it/s]
# Validation DataLoader 0:  97%|█████████▋| 77/79 [00:01<00:00, 48.44it/s]
# Validation DataLoader 0:  99%|█████████▊| 78/79 [00:01<00:00, 48.36it/s]
# Validation DataLoader 0: 100%|██████████| 79/79 [00:01<00:00, 48.83it/s]
# Epoch 8: 100%|██████████| 391/391 [00:11<00:00, 32.89it/s, train_loss=0.460, train_acc=0.812, val_loss=0.647, val_acc=0.776]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏         | 1/79 [00:00<00:01, 70.92it/s]
# Validation DataLoader 0:   3%|▎         | 2/79 [00:00<00:01, 65.07it/s]
# Validation DataLoader 0:   4%|▍         | 3/79 [00:00<00:01, 71.51it/s]
# Validation DataLoader 0:   5%|▌         | 4/79 [00:00<00:01, 57.62it/s]
# Validation DataLoader 0:   6%|▋         | 5/79 [00:00<00:01, 61.78it/s]
# Validation DataLoader 0:   8%|▊         | 6/79 [00:00<00:01, 58.79it/s]
# Validation DataLoader 0:   9%|▉         | 7/79 [00:00<00:01, 62.85it/s]
# Validation DataLoader 0:  10%|█         | 8/79 [00:00<00:01, 57.87it/s]
# Validation DataLoader 0:  11%|█▏        | 9/79 [00:00<00:01, 61.09it/s]
# Validation DataLoader 0:  13%|█▎        | 10/79 [00:00<00:01, 57.79it/s]
# Validation DataLoader 0:  14%|█▍        | 11/79 [00:00<00:01, 60.36it/s]
# Validation DataLoader 0:  15%|█▌        | 12/79 [00:00<00:01, 56.48it/s]
# Validation DataLoader 0:  16%|█▋        | 13/79 [00:00<00:01, 58.38it/s]
# Validation DataLoader 0:  18%|█▊        | 14/79 [00:00<00:01, 56.75it/s]
# Validation DataLoader 0:  19%|█▉        | 15/79 [00:00<00:01, 59.05it/s]
# Validation DataLoader 0:  20%|██        | 16/79 [00:00<00:01, 55.06it/s]
# Validation DataLoader 0:  22%|██▏       | 17/79 [00:00<00:01, 57.11it/s]
# Validation DataLoader 0:  23%|██▎       | 18/79 [00:00<00:01, 53.78it/s]
# Validation DataLoader 0:  24%|██▍       | 19/79 [00:00<00:01, 55.59it/s]
# Validation DataLoader 0:  25%|██▌       | 20/79 [00:00<00:01, 52.89it/s]
# Validation DataLoader 0:  27%|██▋       | 21/79 [00:00<00:01, 54.46it/s]
# Validation DataLoader 0:  28%|██▊       | 22/79 [00:00<00:01, 52.10it/s]
# Validation DataLoader 0:  29%|██▉       | 23/79 [00:00<00:01, 53.54it/s]
# Validation DataLoader 0:  30%|███       | 24/79 [00:00<00:01, 51.48it/s]
# Validation DataLoader 0:  32%|███▏      | 25/79 [00:00<00:01, 52.80it/s]
# Validation DataLoader 0:  33%|███▎      | 26/79 [00:00<00:01, 50.96it/s]
# Validation DataLoader 0:  34%|███▍      | 27/79 [00:00<00:00, 52.19it/s]
# Validation DataLoader 0:  35%|███▌      | 28/79 [00:00<00:01, 50.54it/s]
# Validation DataLoader 0:  37%|███▋      | 29/79 [00:00<00:00, 51.67it/s]
# Validation DataLoader 0:  38%|███▊      | 30/79 [00:00<00:00, 50.18it/s]
# Validation DataLoader 0:  39%|███▉      | 31/79 [00:00<00:00, 51.23it/s]
# Validation DataLoader 0:  41%|████      | 32/79 [00:00<00:00, 49.83it/s]
# Validation DataLoader 0:  42%|████▏     | 33/79 [00:00<00:00, 50.83it/s]
# Validation DataLoader 0:  43%|████▎     | 34/79 [00:00<00:00, 49.56it/s]
# Validation DataLoader 0:  44%|████▍     | 35/79 [00:00<00:00, 50.48it/s]
# Validation DataLoader 0:  46%|████▌     | 36/79 [00:00<00:00, 49.31it/s]
# Validation DataLoader 0:  47%|████▋     | 37/79 [00:00<00:00, 50.18it/s]
# Validation DataLoader 0:  48%|████▊     | 38/79 [00:00<00:00, 49.09it/s]
# Validation DataLoader 0:  49%|████▉     | 39/79 [00:00<00:00, 49.92it/s]
# Validation DataLoader 0:  51%|█████     | 40/79 [00:00<00:00, 48.89it/s]
# Validation DataLoader 0:  52%|█████▏    | 41/79 [00:00<00:00, 49.68it/s]
# Validation DataLoader 0:  53%|█████▎    | 42/79 [00:00<00:00, 48.73it/s]
# Validation DataLoader 0:  54%|█████▍    | 43/79 [00:00<00:00, 49.47it/s]
# Validation DataLoader 0:  56%|█████▌    | 44/79 [00:00<00:00, 48.56it/s]
# Validation DataLoader 0:  57%|█████▋    | 45/79 [00:00<00:00, 49.27it/s]
# Validation DataLoader 0:  58%|█████▊    | 46/79 [00:00<00:00, 48.41it/s]
# Validation DataLoader 0:  59%|█████▉    | 47/79 [00:00<00:00, 49.09it/s]
# Validation DataLoader 0:  61%|██████    | 48/79 [00:00<00:00, 48.28it/s]
# Validation DataLoader 0:  62%|██████▏   | 49/79 [00:01<00:00, 48.92it/s]
# Validation DataLoader 0:  63%|██████▎   | 50/79 [00:01<00:00, 48.15it/s]
# Validation DataLoader 0:  65%|██████▍   | 51/79 [00:01<00:00, 48.77it/s]
# Validation DataLoader 0:  66%|██████▌   | 52/79 [00:01<00:00, 48.06it/s]
# Validation DataLoader 0:  67%|██████▋   | 53/79 [00:01<00:00, 48.65it/s]
# Validation DataLoader 0:  68%|██████▊   | 54/79 [00:01<00:00, 47.96it/s]
# Validation DataLoader 0:  70%|██████▉   | 55/79 [00:01<00:00, 48.53it/s]
# Validation DataLoader 0:  71%|███████   | 56/79 [00:01<00:00, 47.87it/s]
# Validation DataLoader 0:  72%|███████▏  | 57/79 [00:01<00:00, 48.42it/s]
# Validation DataLoader 0:  73%|███████▎  | 58/79 [00:01<00:00, 47.79it/s]
# Validation DataLoader 0:  75%|███████▍  | 59/79 [00:01<00:00, 48.32it/s]
# Validation DataLoader 0:  76%|███████▌  | 60/79 [00:01<00:00, 47.71it/s]
# Validation DataLoader 0:  77%|███████▋  | 61/79 [00:01<00:00, 48.22it/s]
# Validation DataLoader 0:  78%|███████▊  | 62/79 [00:01<00:00, 47.64it/s]
# Validation DataLoader 0:  80%|███████▉  | 63/79 [00:01<00:00, 48.14it/s]
# Validation DataLoader 0:  81%|████████  | 64/79 [00:01<00:00, 47.56it/s]
# Validation DataLoader 0:  82%|████████▏ | 65/79 [00:01<00:00, 48.05it/s]
# Validation DataLoader 0:  84%|████████▎ | 66/79 [00:01<00:00, 47.50it/s]
# Validation DataLoader 0:  85%|████████▍ | 67/79 [00:01<00:00, 47.98it/s]
# Validation DataLoader 0:  86%|████████▌ | 68/79 [00:01<00:00, 47.35it/s]
# Validation DataLoader 0:  87%|████████▋ | 69/79 [00:01<00:00, 47.68it/s]
# Validation DataLoader 0:  89%|████████▊ | 70/79 [00:01<00:00, 47.66it/s]
# Validation DataLoader 0:  90%|████████▉ | 71/79 [00:01<00:00, 47.99it/s]
# Validation DataLoader 0:  91%|█████████ | 72/79 [00:01<00:00, 47.96it/s]
# Validation DataLoader 0:  92%|█████████▏| 73/79 [00:01<00:00, 48.27it/s]
# Validation DataLoader 0:  94%|█████████▎| 74/79 [00:01<00:00, 48.24it/s]
# Validation DataLoader 0:  95%|█████████▍| 75/79 [00:01<00:00, 48.55it/s]
# Validation DataLoader 0:  96%|█████████▌| 76/79 [00:01<00:00, 48.56it/s]
# Validation DataLoader 0:  97%|█████████▋| 77/79 [00:01<00:00, 48.97it/s]
# Validation DataLoader 0:  99%|█████████▊| 78/79 [00:01<00:00, 48.97it/s]
# Validation DataLoader 0: 100%|██████████| 79/79 [00:01<00:00, 49.44it/s]
# Epoch 9: 100%|██████████| 391/391 [00:12<00:00, 31.99it/s, train_loss=0.701, train_acc=0.750, val_loss=0.635, val_acc=0.783]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏         | 1/79 [00:00<00:00, 99.46it/s]
# Validation DataLoader 0:   3%|▎         | 2/79 [00:00<00:01, 64.02it/s]
# Validation DataLoader 0:   4%|▍         | 3/79 [00:00<00:01, 62.24it/s]
# Validation DataLoader 0:   5%|▌         | 4/79 [00:00<00:01, 52.54it/s]
# Validation DataLoader 0:   6%|▋         | 5/79 [00:00<00:01, 53.86it/s]
# Validation DataLoader 0:   8%|▊         | 6/79 [00:00<00:01, 50.04it/s]
# Validation DataLoader 0:   9%|▉         | 7/79 [00:00<00:01, 51.15it/s]
# Validation DataLoader 0:  10%|█         | 8/79 [00:00<00:01, 48.03it/s]
# Validation DataLoader 0:  11%|█▏        | 9/79 [00:00<00:01, 49.45it/s]
# Validation DataLoader 0:  13%|█▎        | 10/79 [00:00<00:01, 50.02it/s]
# Validation DataLoader 0:  14%|█▍        | 11/79 [00:00<00:01, 50.95it/s]
# Validation DataLoader 0:  15%|█▌        | 12/79 [00:00<00:01, 51.26it/s]
# Validation DataLoader 0:  16%|█▋        | 13/79 [00:00<00:01, 51.84it/s]
# Validation DataLoader 0:  18%|█▊        | 14/79 [00:00<00:01, 52.57it/s]
# Validation DataLoader 0:  19%|█▉        | 15/79 [00:00<00:01, 52.31it/s]
# Validation DataLoader 0:  20%|██        | 16/79 [00:00<00:01, 53.65it/s]
# Validation DataLoader 0:  22%|██▏       | 17/79 [00:00<00:01, 52.96it/s]
# Validation DataLoader 0:  23%|██▎       | 18/79 [00:00<00:01, 54.19it/s]
# Validation DataLoader 0:  24%|██▍       | 19/79 [00:00<00:01, 53.02it/s]
# Validation DataLoader 0:  25%|██▌       | 20/79 [00:00<00:01, 54.10it/s]
# Validation DataLoader 0:  27%|██▋       | 21/79 [00:00<00:01, 53.23it/s]
# Validation DataLoader 0:  28%|██▊       | 22/79 [00:00<00:01, 54.38it/s]
# Validation DataLoader 0:  29%|██▉       | 23/79 [00:00<00:01, 53.78it/s]
# Validation DataLoader 0:  30%|███       | 24/79 [00:00<00:01, 54.90it/s]
# Validation DataLoader 0:  32%|███▏      | 25/79 [00:00<00:00, 54.43it/s]
# Validation DataLoader 0:  33%|███▎      | 26/79 [00:00<00:00, 55.75it/s]
# Validation DataLoader 0:  34%|███▍      | 27/79 [00:00<00:00, 53.45it/s]
# Validation DataLoader 0:  35%|███▌      | 28/79 [00:00<00:00, 54.32it/s]
# Validation DataLoader 0:  37%|███▋      | 29/79 [00:00<00:00, 53.77it/s]
# Validation DataLoader 0:  38%|███▊      | 30/79 [00:00<00:00, 54.64it/s]
# Validation DataLoader 0:  39%|███▉      | 31/79 [00:00<00:00, 54.14it/s]
# Validation DataLoader 0:  41%|████      | 32/79 [00:00<00:00, 54.95it/s]
# Validation DataLoader 0:  42%|████▏     | 33/79 [00:00<00:00, 54.71it/s]
# Validation DataLoader 0:  43%|████▎     | 34/79 [00:00<00:00, 55.22it/s]
# Validation DataLoader 0:  44%|████▍     | 35/79 [00:00<00:00, 55.07it/s]
# Validation DataLoader 0:  46%|████▌     | 36/79 [00:00<00:00, 55.63it/s]
# Validation DataLoader 0:  47%|████▋     | 37/79 [00:00<00:00, 55.18it/s]
# Validation DataLoader 0:  48%|████▊     | 38/79 [00:00<00:00, 55.72it/s]
# Validation DataLoader 0:  49%|████▉     | 39/79 [00:00<00:00, 55.27it/s]
# Validation DataLoader 0:  51%|█████     | 40/79 [00:00<00:00, 55.79it/s]
# Validation DataLoader 0:  52%|█████▏    | 41/79 [00:00<00:00, 55.39it/s]
# Validation DataLoader 0:  53%|█████▎    | 42/79 [00:00<00:00, 55.91it/s]
# Validation DataLoader 0:  54%|█████▍    | 43/79 [00:00<00:00, 55.39it/s]
# Validation DataLoader 0:  56%|█████▌    | 44/79 [00:00<00:00, 56.05it/s]
# Validation DataLoader 0:  57%|█████▋    | 45/79 [00:00<00:00, 55.04it/s]
# Validation DataLoader 0:  58%|█████▊    | 46/79 [00:00<00:00, 55.67it/s]
# Validation DataLoader 0:  59%|█████▉    | 47/79 [00:00<00:00, 54.51it/s]
# Validation DataLoader 0:  61%|██████    | 48/79 [00:00<00:00, 55.11it/s]
# Validation DataLoader 0:  62%|██████▏   | 49/79 [00:00<00:00, 54.06it/s]
# Validation DataLoader 0:  63%|██████▎   | 50/79 [00:00<00:00, 54.60it/s]
# Validation DataLoader 0:  65%|██████▍   | 51/79 [00:00<00:00, 53.61it/s]
# Validation DataLoader 0:  66%|██████▌   | 52/79 [00:00<00:00, 54.15it/s]
# Validation DataLoader 0:  67%|██████▋   | 53/79 [00:00<00:00, 53.20it/s]
# Validation DataLoader 0:  68%|██████▊   | 54/79 [00:01<00:00, 53.73it/s]
# Validation DataLoader 0:  70%|██████▉   | 55/79 [00:01<00:00, 52.87it/s]
# Validation DataLoader 0:  71%|███████   | 56/79 [00:01<00:00, 53.39it/s]
# Validation DataLoader 0:  72%|███████▏  | 57/79 [00:01<00:00, 52.53it/s]
# Validation DataLoader 0:  73%|███████▎  | 58/79 [00:01<00:00, 53.03it/s]
# Validation DataLoader 0:  75%|███████▍  | 59/79 [00:01<00:00, 52.20it/s]
# Validation DataLoader 0:  76%|███████▌  | 60/79 [00:01<00:00, 52.69it/s]
# Validation DataLoader 0:  77%|███████▋  | 61/79 [00:01<00:00, 51.99it/s]
# Validation DataLoader 0:  78%|███████▊  | 62/79 [00:01<00:00, 52.46it/s]
# Validation DataLoader 0:  80%|███████▉  | 63/79 [00:01<00:00, 51.76it/s]
# Validation DataLoader 0:  81%|████████  | 64/79 [00:01<00:00, 52.18it/s]
# Validation DataLoader 0:  82%|████████▏ | 65/79 [00:01<00:00, 51.56it/s]
# Validation DataLoader 0:  84%|████████▎ | 66/79 [00:01<00:00, 51.91it/s]
# Validation DataLoader 0:  85%|████████▍ | 67/79 [00:01<00:00, 51.30it/s]
# Validation DataLoader 0:  86%|████████▌ | 68/79 [00:01<00:00, 51.73it/s]
# Validation DataLoader 0:  87%|████████▋ | 69/79 [00:01<00:00, 51.14it/s]
# Validation DataLoader 0:  89%|████████▊ | 70/79 [00:01<00:00, 51.57it/s]
# Validation DataLoader 0:  90%|████████▉ | 71/79 [00:01<00:00, 50.96it/s]
# Validation DataLoader 0:  91%|█████████ | 72/79 [00:01<00:00, 51.38it/s]
# Validation DataLoader 0:  92%|█████████▏| 73/79 [00:01<00:00, 50.73it/s]
# Validation DataLoader 0:  94%|█████████▎| 74/79 [00:01<00:00, 51.03it/s]
# Validation DataLoader 0:  95%|█████████▍| 75/79 [00:01<00:00, 50.91it/s]
# Validation DataLoader 0:  96%|█████████▌| 76/79 [00:01<00:00, 51.19it/s]
# Validation DataLoader 0:  97%|█████████▋| 77/79 [00:01<00:00, 51.07it/s]
# Validation DataLoader 0:  99%|█████████▊| 78/79 [00:01<00:00, 51.51it/s]
# Validation DataLoader 0: 100%|██████████| 79/79 [00:01<00:00, 51.98it/s]
# Epoch 9: 100%|██████████| 391/391 [00:13<00:00, 28.14it/s, train_loss=0.701, train_acc=0.750, val_loss=0.636, val_acc=0.783]
# Calculating final confusion matrix for artifact logging...
#
# Finished Training. Best accuracy: 78.34%
# Epoch 9: 100%|██████████| 391/391 [00:36<00:00, 10.64it/s, train_loss=0.701, train_acc=0.750, val_loss=0.636, val_acc=0.783]
#
# MLflow run id: 2de85855519748c4b0ca1a5bfec0b2ef
# To view results run mlflow ui

# %% [markdown]
# ## MLflow UI Setup
#
# ### Navigating the UI
#
# * The `helper_utils.show_ui_navigation_instructions()` function will render a step-by-step guide on how to use the MLflow UI.
#     * To show the instructions, pass `display_instructions=True`.
#     * To hide the instructions, you can omit the argument, as it defaults to `False`.

# %%
# Set the parameter to True to see the instructions
helper_utils.show_ui_navigation_instructions(display_instructions=True)

# %% [markdown]
# ### Running the MLflow UI
#
# * Use `start_mlflow_ui()` to launch the MLflow UI server with nginx reverse proxy support.
# * The server will run in the background, allowing you to continue with the notebook without interruption.

# %%
# Start the MLflow UI server (runs in background)
mlflow_process = helper_utils.start_mlflow_ui()
# Out:
# Starting MLflow UI...
# Waiting for server to start...
#
# ============================================================
# MLflow UI is running in the background!
# ============================================================
# Access from: [Open MLflow UI](/mlflow/)
# The server is running in the background. You can continue with the notebook.
# To stop the server later, run: process.terminate()
# ============================================================

# %% [markdown]
# ## Alternative to UI: Viewing MLflow Logs via Python Client in Notebook
#
# While the MLflow UI provides a comprehensive graphical interface for exploring your experiment runs, there are times when accessing and reviewing your MLflow logs directly within your Jupyter Notebook can be more convenient or suitable for specific workflows. This section demonstrates how you can use MLflow's Python client to programmatically retrieve and display information about your experiment runs without leaving the notebook environment.
#
# The approach shown here offers a minimalistic view, primarily focusing on fetching details for specific runs based on their Run IDs. However, this is just a starting point. The MLflow Python client is quite powerful, and you can easily adapt and expand upon these methods to customize the information you want to extract and the way it's presented, tailoring it to your specific analytical or reporting needs.

# %% [markdown]
# * Initialize [MLflow Client](https://mlflow.org/docs/1.25.1/python_api/mlflow.tracking.html) to interact with MLflow.
# * [Search](https://mlflow.org/docs/latest/search-experiments/) and display all experiments and, for each, list their runs with start times and names, _prompting you to copy a run_id_.

# %%
client = mlflow.tracking.MlflowClient()

print("MLflow Client Initialized.\n")
print("Listing all Run IDs from all experiments (descending by start time)...\n")

experiments = client.search_experiments()

if not experiments:
    print("No experiments found.")
else:
    all_runs_listed = False
    for exp in experiments:
        print(f"Experiment: {exp.name} (ID: {exp.experiment_id})")
        runs = client.search_runs(exp.experiment_id, order_by=["attributes.start_time DESC"])
        
        if not runs:
            print("  No runs found in this experiment.")
        else:
            all_runs_listed = True
            for run_info in runs:
                start_time_seconds = run_info.info.start_time / 1000.0
                start_time_formatted = datetime.datetime.fromtimestamp(start_time_seconds).strftime('%Y-%m-%d %H:%M:%S')
                
                run_name_tag = run_info.data.tags.get('mlflow.runName')
                display_name = f" (Name: {run_name_tag})" if run_name_tag else ""
                print(f"  Run ID: {run_info.info.run_id}{display_name} - Started: {start_time_formatted}")
        print("-" * 30)
    if not all_runs_listed:
        print("\nNo runs found across any experiment.")

print("\nCopy the Run ID you want to inspect from the list above.")
# Out:
# MLflow Client Initialized.
#
# Listing all Run IDs from all experiments (descending by start time)...
#
# Experiment: CIFAR10_CNN (ID: 366944453960856762)
#   Run ID: 2de85855519748c4b0ca1a5bfec0b2ef (Name: omniscient-rat-224) - Started: 2026-01-04 08:53:36
# ------------------------------
# Experiment: Default (ID: 0)
#   No runs found in this experiment.
# ------------------------------
#
# Copy the Run ID you want to inspect from the list above.

# %% [markdown]
# * Copy a specific Run ID from the displayed list above, which you want to inspect.
#     * Set (paste) this as a `str` in `run_id`.

# %%
# Paste the Run ID you copied into the run_id variable below.
run_id = "2de85855519748c4b0ca1a5bfec0b2ef"  # <-- PASTE YOUR RUN ID BETWEEN THE QUOTES

# %% [markdown]
# * Use `display_mlflow_run_details` function to fetch and display a formatted summary of the run, which includes:
#     * The selected **Run ID** and the name/ID of the experiment it belongs to.
#     * The values of key **hyperparameters** that were logged for the run.
#     * The final values of all tracked **metrics**.
#     * A list of all **artifacts** associated with the run.

# %%
try:
    # Validate the run_id and print a confirmation.
    if not run_id or not run_id.strip():
        print("Error: Please paste a valid Run ID. It cannot be empty or just whitespace.")
    else:
        print(f"Run ID set to: {run_id}")
        # Call the helper function to display the run details.
        helper_utils.display_mlflow_run_details(run_id)

except NameError:
    print("Error: The 'run_id' variable is not defined. Please make sure it's set in the try block.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Run ID set to: 2de85855519748c4b0ca1a5bfec0b2ef
# MLflow Client Initialized. Fetching details for Run ID: 2de85855519748c4b0ca1a5bfec0b2ef
#
# Details for Run ID: 2de85855519748c4b0ca1a5bfec0b2ef
# Belongs to Experiment: CIFAR10_CNN (ID: 366944453960856762)
#
#   Parameters:
#     - model_type: SimpleCNN
#     - optimizer: Adam
#     - initial_lr: 0.001
#     - scheduler: ReduceLROnPlateau
#     - batch_size: 128
#     - random_seed: 42
#
#   Metrics (final values):
#     - train_loss: 0.7014 (logged per epoch)
#     - val_loss: 0.6355 (logged per epoch)
#     - accuracy: 78.3400 (logged per epoch)
#     - learning_rate: 0.0010 (logged per epoch)
#     - best_accuracy: 78.3400
#
#   Artifacts:
#     - Checkpoint 'best_model_checkpoint_epoch_1.pt' was saved.
#     - Checkpoint 'best_model_checkpoint_epoch_10.pt' was saved.
#     - Checkpoint 'best_model_checkpoint_epoch_2.pt' was saved.
#     - Checkpoint 'best_model_checkpoint_epoch_3.pt' was saved.
#     - Checkpoint 'best_model_checkpoint_epoch_4.pt' was saved.
#     - Checkpoint 'best_model_checkpoint_epoch_5.pt' was saved.
#     - Checkpoint 'best_model_checkpoint_epoch_6.pt' was saved.
#     - Checkpoint 'best_model_checkpoint_epoch_7.pt' was saved.
#     - Checkpoint 'best_model_checkpoint_epoch_8.pt' was saved.
#     - Checkpoint 'best_model_checkpoint_epoch_9.pt' was saved.
#     - PyTorch Model 'cifar10_cnn_model_final' was saved (directory).
#     - Artifact 'confusion_matrix.png' was saved.
#   ---

# %% [markdown]
# ## Conclusion
#
# Congratulations on completing this lab! You have successfully trained a CNN using **PyTorch Lightning** and, more importantly, implemented a systematic workflow to manage and preserve your results.
#
# You've put foundational MLOps principles into practice with modern deep learning tools. By using **PyTorch Lightning**, you've seen how to organize your code into clean, reusable components (`LightningModule` and `LightningDataModule`) and how to extend functionality with custom **Callbacks**. This approach dramatically simplifies your training code while maintaining full flexibility.
#
# You implemented **checkpointing** to not only save your final model but also the best-performing version during training, complete with its optimizer state. By logging this checkpoint and other **artifacts** like the confusion matrix through your custom MLflow callback, you've moved past the chaos of managing countless model files with confusing names.
#
# By combining **Lightning** with **MLflow**, you transformed your training process from a temporary session into a series of well-documented, reproducible experiments. Every hyperparameter, metric, and model file is now neatly organized and ready for comparison. The skills you've developed here in modern deep learning frameworks, serialization, and experiment tracking are fundamental for preparing any model for real-world deployment. You are now well-equipped to build more reliable and structured machine learning systems.
